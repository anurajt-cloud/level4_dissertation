# %% [markdown]
# -------------------------------------
# # ECG Beat classification:
# ### Model - CNN
#
# ### Data Method - Patient leave-out
#
# -------------------------------------

# %% [markdown]
# ### Imports

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import os
import seaborn as sns
from sklearn import *
from sklearn.metrics import *
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D, LeakyReLU
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Add
from tensorflow.keras.layers import Activation
import itertools
import time
from sklearn.utils import resample
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# from google.colab import drive
# drive.mount('/content/drive')

print("You are using Tensorflow version", tf.__version__)

print(tf.config.list_physical_devices('GPU'))
# Out:
# You are using Tensorflow version 2.1.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# path = './drive/MyDrive/Colab_Notebooks/ECG_with_Expected_gradients/'
path = './'

# %%
os.listdir(path)
# Out:
# ['CNN_leaveout_patients_train_test.ipynb',
#  'Data',
#  'ECG',
#  'eval_data_10k',
#  'RAN_MODELS',
#  'reserver_eval_data',
#  'tryCNN_holdout_patients_IG_train_test.ipynb',
#  'tryLSTM_leaveout_patients_EG_train_test.ipynb']

# %% [markdown]
# ### Loading data

# %%
train_c1 = np.genfromtxt(path+'Data/train_patients_sc.csv', delimiter=',')
train_c0 = np.genfromtxt(path+'Data/train_patients_fc.csv', delimiter=',')
test_c1 = np.genfromtxt(path+'Data/test_patients_sc.csv', delimiter=',')
test_c0 = np.genfromtxt(path+'Data/test_patients_fc.csv', delimiter=',')

train_x_c01 = np.concatenate((train_c0[:, :-2], train_c1[:, :-2]), axis=1)
train_y_c01 = np.concatenate((train_c0[:, -2:], train_c1[:, -2:]), axis=1)

test_x_c01 = np.concatenate((test_c0[:, :-2], test_c1[:, :-2]), axis=1)
test_y_c01 = np.concatenate((test_c0[:, -2:], test_c0[:, -2:]), axis=1)

train_x = train_x_c01.reshape(-1, train_x_c01.shape[1], 1).astype('float32')
test_x = test_x_c01.reshape(-1, test_x_c01.shape[1], 1).astype('float32')

train_y = tf.keras.utils.to_categorical(train_y_c01[:,0])
test_y = tf.keras.utils.to_categorical(test_y_c01[:,0])

print("Train:")
print("x:", train_x.shape, "y:", train_y.shape)
print("Test")
print("x:", test_x.shape, "y:", test_y.shape)
# Out:
# Train:
# x: (32048, 920, 1) y: (32048, 9)
# Test
# x: (9902, 920, 1) y: (9902, 9)

# %% [markdown]
# ### Creating a performance metrics function

# %%
def showResults(test, pred, model_name):
    accuracy = accuracy_score(test, pred)
    precision= precision_score(test, pred, average='macro')
    recall = recall_score(test, pred, average = 'macro')
    f1score_macro = f1_score(test, pred, average='macro') 
    f1score_micro = f1_score(test, pred, average='micro') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("Recall : {}".format(recall))
    print("f1score macro : {}".format(f1score_macro))
    print("f1score micro : {}".format(f1score_micro))
    cm=confusion_matrix(test, pred, labels=[1,2,3,4,5,6,7,8])
    return (model_name, round(accuracy,3), round(precision,3) , round(recall,3) , round(f1score_macro,3), 
            round(f1score_micro, 3), cm)

# %% [markdown]
# ### Function for building the CNN model

# %%
# Defining the model
verbose = 1
epochs = 10
batch_size = 50

opt = Adam(learning_rate=0.001)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
        factor=0.1,
        patience=2,
        min_lr=0.001 * 0.001)

def getCNNModel():
    
    input = keras.layers.Input(shape=(train_x.shape[1],train_x.shape[2]))
    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)

    #block 2

    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)
    x = keras.layers.Dropout(0.2)(x)

    #block 3
    for i in range(4):


        shortcut = MaxPooling1D(pool_size=1)(x)

        filters = 64 * ((i//2)+1)
        # print("Filter size = "+str(filters))
        x = keras.layers.Conv1D(kernel_size=16, filters=filters, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.LeakyReLU(alpha=0.3)(x)

        x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)

        x = keras.layers.LeakyReLU(alpha=0.3)(x)
        x = keras.layers.Dropout(0.2)(x)
    

        x = tf.keras.layers.Add()([x, shortcut])


    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)
    x = keras.layers.Flatten()(x)
    out = keras.layers.Dense(9, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=[input], outputs=out)
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    return model

# %% [markdown]
# ### List of models

# %%
cnn1 = getCNNModel()
cnn2 = getCNNModel()
cnn3 = getCNNModel()
cnn4 = getCNNModel()
cnn5 = getCNNModel()
cnn6 = getCNNModel()
cnn7 = getCNNModel()
cnn8 = getCNNModel()
cnn9 = getCNNModel()
cnn10 = getCNNModel()

modellist = [cnn1, cnn2, cnn3, cnn4, cnn5, cnn6, cnn7, cnn8, cnn9, cnn10]

# %% [markdown]
# ### Fitting all the models

# %%
modelhistory = []
for m in range(len(modellist)):
  print("*"*10,"Model",m+1,"*"*10)
  modelhistory.append(modellist[m].fit(train_x,train_y,epochs=epochs,batch_size=batch_size,validation_split=0.1,verbose=verbose, callbacks=[reduce_lr]))
# Out:
# ********** Model 1 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 26s 910us/sample - loss: 0.3156 - accuracy: 0.9249 - val_loss: 0.2241 - val_accuracy: 0.9473
# Epoch 2/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.1386 - accuracy: 0.9642 - val_loss: 0.1320 - val_accuracy: 0.9710
# Epoch 3/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.1060 - accuracy: 0.9719 - val_loss: 0.1606 - val_accuracy: 0.9604
# Epoch 4/10
# 28843/28843 [==============================] - 23s 814us/sample - loss: 0.0763 - accuracy: 0.9778 - val_loss: 0.1019 - val_accuracy: 0.9813
# Epoch 5/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0678 - accuracy: 0.9804 - val_loss: 0.2065 - val_accuracy: 0.9501
# Epoch 6/10
# 28843/28843 [==============================] - 24s 824us/sample - loss: 0.0609 - accuracy: 0.9819 - val_loss: 0.0840 - val_accuracy: 0.9828
# Epoch 7/10
# 28843/28843 [==============================] - 24s 822us/sample - loss: 0.0549 - accuracy: 0.9840 - val_loss: 0.0994 - val_accuracy: 0.9785
# Epoch 8/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0440 - accuracy: 0.9875 - val_loss: 0.0849 - val_accuracy: 0.9850
# Epoch 9/10
# 28843/28843 [==============================] - 24s 825us/sample - loss: 0.0204 - accuracy: 0.9941 - val_loss: 0.0428 - val_accuracy: 0.9919
# Epoch 10/10
# 28843/28843 [==============================] - 24s 826us/sample - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0440 - val_accuracy: 0.9888
# ********** Model 2 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 26s 895us/sample - loss: 0.1865 - accuracy: 0.9447 - val_loss: 0.0886 - val_accuracy: 0.9719
# Epoch 2/10
# 28843/28843 [==============================] - 24s 828us/sample - loss: 0.0752 - accuracy: 0.9777 - val_loss: 0.0748 - val_accuracy: 0.9769
# Epoch 3/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0549 - accuracy: 0.9826 - val_loss: 0.0655 - val_accuracy: 0.9810
# Epoch 4/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.0453 - accuracy: 0.9859 - val_loss: 0.0622 - val_accuracy: 0.9813
# Epoch 5/10
# 28843/28843 [==============================] - 24s 822us/sample - loss: 0.0345 - accuracy: 0.9889 - val_loss: 0.0486 - val_accuracy: 0.9853
# Epoch 6/10
# 28843/28843 [==============================] - 24s 822us/sample - loss: 0.0288 - accuracy: 0.9906 - val_loss: 0.0580 - val_accuracy: 0.9822
# Epoch 7/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0271 - accuracy: 0.9918 - val_loss: 0.0408 - val_accuracy: 0.9897
# Epoch 8/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0233 - accuracy: 0.9931 - val_loss: 0.0439 - val_accuracy: 0.9888
# Epoch 9/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0221 - accuracy: 0.9932 - val_loss: 0.0588 - val_accuracy: 0.9850
# Epoch 10/10
# 28843/28843 [==============================] - 24s 821us/sample - loss: 0.0106 - accuracy: 0.9975 - val_loss: 0.0393 - val_accuracy: 0.9897
# ********** Model 3 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 26s 899us/sample - loss: 0.2755 - accuracy: 0.9154 - val_loss: 0.1514 - val_accuracy: 0.9554
# Epoch 2/10
# 28843/28843 [==============================] - 24s 822us/sample - loss: 0.1403 - accuracy: 0.9577 - val_loss: 0.1242 - val_accuracy: 0.9626
# Epoch 3/10
# 28843/28843 [==============================] - 24s 825us/sample - loss: 0.1162 - accuracy: 0.9643 - val_loss: 0.1070 - val_accuracy: 0.9694
# Epoch 4/10
# 28843/28843 [==============================] - 24s 824us/sample - loss: 0.0993 - accuracy: 0.9695 - val_loss: 0.0929 - val_accuracy: 0.9713
# Epoch 5/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0876 - accuracy: 0.9742 - val_loss: 0.0855 - val_accuracy: 0.9729
# Epoch 6/10
# 28843/28843 [==============================] - 24s 824us/sample - loss: 0.0778 - accuracy: 0.9767 - val_loss: 0.0739 - val_accuracy: 0.9769
# Epoch 7/10
# 28843/28843 [==============================] - 24s 825us/sample - loss: 0.0694 - accuracy: 0.9807 - val_loss: 0.0708 - val_accuracy: 0.9782
# Epoch 8/10
# 28843/28843 [==============================] - 24s 825us/sample - loss: 0.0636 - accuracy: 0.9817 - val_loss: 0.0638 - val_accuracy: 0.9800
# Epoch 9/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0581 - accuracy: 0.9844 - val_loss: 0.0588 - val_accuracy: 0.9800
# Epoch 10/10
# 28843/28843 [==============================] - 24s 824us/sample - loss: 0.0525 - accuracy: 0.9858 - val_loss: 0.0540 - val_accuracy: 0.9835
# ********** Model 4 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 25s 881us/sample - loss: 0.2750 - accuracy: 0.9165 - val_loss: 0.1453 - val_accuracy: 0.9507
# Epoch 2/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.1317 - accuracy: 0.9595 - val_loss: 0.1146 - val_accuracy: 0.9647
# Epoch 3/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.1083 - accuracy: 0.9671 - val_loss: 0.0996 - val_accuracy: 0.9688
# Epoch 4/10
# 28843/28843 [==============================] - 24s 815us/sample - loss: 0.0937 - accuracy: 0.9726 - val_loss: 0.0855 - val_accuracy: 0.9757
# Epoch 5/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.0831 - accuracy: 0.9766 - val_loss: 0.0792 - val_accuracy: 0.9744
# Epoch 6/10
# 28843/28843 [==============================] - 24s 815us/sample - loss: 0.0741 - accuracy: 0.9790 - val_loss: 0.0724 - val_accuracy: 0.9785
# Epoch 7/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.0681 - accuracy: 0.9814 - val_loss: 0.0658 - val_accuracy: 0.9800
# Epoch 8/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.0612 - accuracy: 0.9834 - val_loss: 0.0615 - val_accuracy: 0.9813
# Epoch 9/10
# 28843/28843 [==============================] - 24s 815us/sample - loss: 0.0574 - accuracy: 0.9840 - val_loss: 0.0587 - val_accuracy: 0.9810
# Epoch 10/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.0528 - accuracy: 0.9858 - val_loss: 0.0557 - val_accuracy: 0.9835
# ********** Model 5 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 25s 879us/sample - loss: 0.2671 - accuracy: 0.9182 - val_loss: 0.1468 - val_accuracy: 0.9576
# Epoch 2/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.1332 - accuracy: 0.9584 - val_loss: 0.1192 - val_accuracy: 0.9629
# Epoch 3/10
# 28843/28843 [==============================] - 24s 815us/sample - loss: 0.1087 - accuracy: 0.9674 - val_loss: 0.1047 - val_accuracy: 0.9663
# Epoch 4/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0931 - accuracy: 0.9712 - val_loss: 0.0925 - val_accuracy: 0.9713
# Epoch 5/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0815 - accuracy: 0.9760 - val_loss: 0.0800 - val_accuracy: 0.9747
# Epoch 6/10
# 28843/28843 [==============================] - 24s 821us/sample - loss: 0.0736 - accuracy: 0.9789 - val_loss: 0.0733 - val_accuracy: 0.9775
# Epoch 7/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0666 - accuracy: 0.9809 - val_loss: 0.0668 - val_accuracy: 0.9785
# Epoch 8/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0610 - accuracy: 0.9825 - val_loss: 0.0649 - val_accuracy: 0.9803
# Epoch 9/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0557 - accuracy: 0.9837 - val_loss: 0.0583 - val_accuracy: 0.9822
# Epoch 10/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0512 - accuracy: 0.9855 - val_loss: 0.0593 - val_accuracy: 0.9807
# ********** Model 6 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 26s 903us/sample - loss: 0.2804 - accuracy: 0.9171 - val_loss: 0.1541 - val_accuracy: 0.9523
# Epoch 2/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.1400 - accuracy: 0.9572 - val_loss: 0.1243 - val_accuracy: 0.9607
# Epoch 3/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.1143 - accuracy: 0.9661 - val_loss: 0.1055 - val_accuracy: 0.9666
# Epoch 4/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.1005 - accuracy: 0.9699 - val_loss: 0.0927 - val_accuracy: 0.9704
# Epoch 5/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0893 - accuracy: 0.9725 - val_loss: 0.0830 - val_accuracy: 0.9747
# Epoch 6/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.0805 - accuracy: 0.9761 - val_loss: 0.0775 - val_accuracy: 0.9785
# Epoch 7/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0727 - accuracy: 0.9776 - val_loss: 0.0726 - val_accuracy: 0.9788
# Epoch 8/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.0670 - accuracy: 0.9807 - val_loss: 0.0657 - val_accuracy: 0.9800
# Epoch 9/10
# 28843/28843 [==============================] - 24s 824us/sample - loss: 0.0612 - accuracy: 0.9830 - val_loss: 0.0621 - val_accuracy: 0.9807
# Epoch 10/10
# 28843/28843 [==============================] - 24s 824us/sample - loss: 0.0567 - accuracy: 0.9842 - val_loss: 0.0571 - val_accuracy: 0.9838
# ********** Model 7 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 25s 884us/sample - loss: 0.2904 - accuracy: 0.9119 - val_loss: 0.1579 - val_accuracy: 0.9520
# Epoch 2/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.1444 - accuracy: 0.9556 - val_loss: 0.1222 - val_accuracy: 0.9604
# Epoch 3/10
# 28843/28843 [==============================] - 24s 815us/sample - loss: 0.1162 - accuracy: 0.9646 - val_loss: 0.1046 - val_accuracy: 0.9647
# Epoch 4/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0984 - accuracy: 0.9708 - val_loss: 0.0886 - val_accuracy: 0.9729
# Epoch 5/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.0861 - accuracy: 0.9744 - val_loss: 0.0778 - val_accuracy: 0.9747
# Epoch 6/10
# 28843/28843 [==============================] - 24s 815us/sample - loss: 0.0757 - accuracy: 0.9775 - val_loss: 0.0712 - val_accuracy: 0.9757
# Epoch 7/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.0680 - accuracy: 0.9808 - val_loss: 0.0651 - val_accuracy: 0.9803
# Epoch 8/10
# 28843/28843 [==============================] - 24s 822us/sample - loss: 0.0603 - accuracy: 0.9827 - val_loss: 0.0617 - val_accuracy: 0.9803
# Epoch 9/10
# 28843/28843 [==============================] - 24s 822us/sample - loss: 0.0553 - accuracy: 0.9850 - val_loss: 0.0556 - val_accuracy: 0.9835
# Epoch 10/10
# 28843/28843 [==============================] - 24s 823us/sample - loss: 0.0505 - accuracy: 0.9864 - val_loss: 0.0518 - val_accuracy: 0.9844
# ********** Model 8 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 26s 886us/sample - loss: 0.2767 - accuracy: 0.9168 - val_loss: 0.1519 - val_accuracy: 0.9538
# Epoch 2/10
# 28843/28843 [==============================] - 24s 822us/sample - loss: 0.1380 - accuracy: 0.9589 - val_loss: 0.1209 - val_accuracy: 0.9629
# Epoch 3/10
# 28843/28843 [==============================] - 24s 821us/sample - loss: 0.1139 - accuracy: 0.9647 - val_loss: 0.1049 - val_accuracy: 0.9672
# Epoch 4/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0986 - accuracy: 0.9712 - val_loss: 0.0958 - val_accuracy: 0.9672
# Epoch 5/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0877 - accuracy: 0.9742 - val_loss: 0.0845 - val_accuracy: 0.9732
# Epoch 6/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0781 - accuracy: 0.9767 - val_loss: 0.0768 - val_accuracy: 0.9766
# Epoch 7/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0717 - accuracy: 0.9794 - val_loss: 0.0728 - val_accuracy: 0.9810
# Epoch 8/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.0657 - accuracy: 0.9804 - val_loss: 0.0703 - val_accuracy: 0.9794
# Epoch 9/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.0589 - accuracy: 0.9833 - val_loss: 0.0658 - val_accuracy: 0.9810
# Epoch 10/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0545 - accuracy: 0.9835 - val_loss: 0.0579 - val_accuracy: 0.9807
# ********** Model 9 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 26s 908us/sample - loss: 0.2673 - accuracy: 0.9169 - val_loss: 0.1482 - val_accuracy: 0.9541
# Epoch 2/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.1330 - accuracy: 0.9599 - val_loss: 0.1183 - val_accuracy: 0.9622
# Epoch 3/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.1091 - accuracy: 0.9673 - val_loss: 0.1029 - val_accuracy: 0.9707
# Epoch 4/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0940 - accuracy: 0.9719 - val_loss: 0.0909 - val_accuracy: 0.9707
# Epoch 5/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0830 - accuracy: 0.9757 - val_loss: 0.0814 - val_accuracy: 0.9769
# Epoch 6/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0746 - accuracy: 0.9778 - val_loss: 0.0743 - val_accuracy: 0.9788
# Epoch 7/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0683 - accuracy: 0.9807 - val_loss: 0.0684 - val_accuracy: 0.9778
# Epoch 8/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0620 - accuracy: 0.9831 - val_loss: 0.0616 - val_accuracy: 0.9819
# Epoch 9/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0569 - accuracy: 0.9844 - val_loss: 0.0564 - val_accuracy: 0.9838
# Epoch 10/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0527 - accuracy: 0.9858 - val_loss: 0.0544 - val_accuracy: 0.9844
# ********** Model 10 **********
# Train on 28843 samples, validate on 3205 samples
# Epoch 1/10
# 28843/28843 [==============================] - 26s 885us/sample - loss: 0.2932 - accuracy: 0.9082 - val_loss: 0.1649 - val_accuracy: 0.9523
# Epoch 2/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.1480 - accuracy: 0.9563 - val_loss: 0.1272 - val_accuracy: 0.9641
# Epoch 3/10
# 28843/28843 [==============================] - 24s 819us/sample - loss: 0.1197 - accuracy: 0.9645 - val_loss: 0.1134 - val_accuracy: 0.9651
# Epoch 4/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.1036 - accuracy: 0.9694 - val_loss: 0.0981 - val_accuracy: 0.9697
# Epoch 5/10
# 28843/28843 [==============================] - 24s 816us/sample - loss: 0.0905 - accuracy: 0.9731 - val_loss: 0.0876 - val_accuracy: 0.9735
# Epoch 6/10
# 28843/28843 [==============================] - 24s 820us/sample - loss: 0.0788 - accuracy: 0.9774 - val_loss: 0.0763 - val_accuracy: 0.9778
# Epoch 7/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0718 - accuracy: 0.9798 - val_loss: 0.0711 - val_accuracy: 0.9807
# Epoch 8/10
# 28843/28843 [==============================] - 24s 817us/sample - loss: 0.0645 - accuracy: 0.9817 - val_loss: 0.0640 - val_accuracy: 0.9832
# Epoch 9/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0588 - accuracy: 0.9841 - val_loss: 0.0605 - val_accuracy: 0.9822
# Epoch 10/10
# 28843/28843 [==============================] - 24s 818us/sample - loss: 0.0543 - accuracy: 0.9850 - val_loss: 0.0606 - val_accuracy: 0.9810

# %% [markdown]
# ### Model predictions

# %%
modelpreds = []
for m in range(len(modellist)):
  print("*"*10, "Model", m+1, "*"*10)
  modelpreds.append(np.argmax(modellist[m].predict(test_x, verbose=1),axis=1))
# Out:
# ********** Model 1 **********
# 9902/9902 [==============================] - 3s 308us/sample
# ********** Model 2 **********
# 9902/9902 [==============================] - 3s 255us/sample
# ********** Model 3 **********
# 9902/9902 [==============================] - 3s 258us/sample
# ********** Model 4 **********
# 9902/9902 [==============================] - 3s 257us/sample
# ********** Model 5 **********
# 9902/9902 [==============================] - 3s 254us/sample
# ********** Model 6 **********
# 9902/9902 [==============================] - 3s 255us/sample
# ********** Model 7 **********
# 9902/9902 [==============================] - 3s 254us/sample
# ********** Model 8 **********
# 9902/9902 [==============================] - 3s 255us/sample
# ********** Model 9 **********
# 9902/9902 [==============================] - 3s 257us/sample
# ********** Model 10 **********
# 9902/9902 [==============================] - 3s 253us/sample

# %% [markdown]
# ### Generating the metrics

# %%
results = []
cnn_actual_value=np.argmax(test_y,axis=1)
for p in range(len(modelpreds)):
  print("*"*10,"Model",p+1,"*"*10)
  results.append(showResults(cnn_actual_value, modelpreds[p],'CNN'+str(p)))
# Out:
# ********** Model 1 **********
# Accuracy  : 0.7532821652191476
# Precision : 0.4074223462638685
# Recall : 0.42022256210830744
# f1score macro : 0.38129544898385725
# f1score micro : 0.7532821652191477
# ********** Model 2 **********
# Accuracy  : 0.7997374267824682
# Precision : 0.4099871818110006
# Recall : 0.4650840780406695
# f1score macro : 0.42180132476823046
# f1score micro : 0.7997374267824682
# ********** Model 3 **********
# Accuracy  : 0.8105433245808927
# Precision : 0.41831518826796943
# Recall : 0.46586113203712703
# f1score macro : 0.42209148972206295
# f1score micro : 0.8105433245808927
# ********** Model 4 **********
# Accuracy  : 0.8276105837204605
# Precision : 0.4127622507039629
# Recall : 0.4840393347578885
# f1score macro : 0.43379302839757183
# f1score micro : 0.8276105837204605
# ********** Model 5 **********
# Accuracy  : 0.8267016764290043
# Precision : 0.41494906651954994
# Recall : 0.48602243525127425
# f1score macro : 0.4399645766106275
# f1score micro : 0.8267016764290043
# ********** Model 6 **********
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy  : 0.8184205211068472
# Precision : 0.41204995039912534
# Recall : 0.4722300907776241
# f1score macro : 0.4279976223564739
# f1score micro : 0.8184205211068472
# ********** Model 7 **********
# Accuracy  : 0.8189254696021006
# Precision : 0.41019521510204937
# Recall : 0.4725669874167345
# f1score macro : 0.42696444344538
# f1score micro : 0.8189254696021006
# ********** Model 8 **********
# Accuracy  : 0.8108462936780448
# Precision : 0.41511005250260613
# Recall : 0.4657831912338075
# f1score macro : 0.4221113207520988
# f1score micro : 0.8108462936780448
# ********** Model 9 **********
# Accuracy  : 0.820137345990709
# Precision : 0.42810061443624314
# Recall : 0.4735707404102315
# f1score macro : 0.4309448697077092
# f1score micro : 0.820137345990709
# ********** Model 10 **********
# Accuracy  : 0.8215512017774187
# Precision : 0.41044167102297896
# Recall : 0.47850857365835464
# f1score macro : 0.43285223973620035
# f1score micro : 0.8215512017774187

# %% [markdown]
# ### Generating the confusion matrices

# %%
cms = []
for p in modelpreds:
  cms.append(confusion_matrix(cnn_actual_value, p, normalize='true'))

# %% [markdown]
# ### Extracting model train and validation accuracy & loss

# %%
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for h in modelhistory:
  modelosses.append(h.history['loss'])
  modeleval_losses.append(h.history['val_loss'])
  modelacc.append(h.history['accuracy'])
  modeleval_acc.append(h.history['val_accuracy'])
modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)
# losses , eval_losses, accuracy, eval_accuracy
history = np.array([modelosses, modeleval_losses, modelacc, modeleval_acc])

# %% [markdown]
# ### Saving the data

# %%
# Saving data LSTM patient leavout
new_path = path+"eval_data_10k/cnn_pl/"

modelpreds = np.array(modelpreds)
results = np.array(results)
cms = np.array(cms)
# modelhistory = np.array(modelhistory)
np.save(new_path+"cnn_modelpreds.npy", modelpreds)
np.save(new_path+"cnn_results.npy", results)
np.save(new_path+"cnn_cms.npy", cms)
np.save(new_path+"cnn_history.npy", history )
# Out:
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """

# %% [markdown]
# Visualising the Mean Confusion Matrix

# %%
categories=['N','L','R','V','A','F','f','/']
cm = np.mean(cms, axis=0)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, xticklabels=categories, yticklabels=categories)
plt.title('CNN - 10k Mean Confusion Matrix')
# plt.savefig("lstm_mean_cm_pl.png", dpi=300)
plt.show()

# %% [markdown]
# ### Mean Metrics

# %%
metrics = ["Accuracy", "Precision", "Recall", "f1-score macro", "f1-score micro"]
mean_metrics = np.mean(results[:,1:6], axis=0)
for i in range(len(mean_metrics)):
  print(metrics[i],":",mean_metrics[i])
# Out:
# Accuracy : 0.8109
# Precision : 0.4138
# Recall : 0.46849999999999997
# f1-score macro : 0.42400000000000004
# f1-score micro : 0.8109

# %% [markdown]
# ### Mesn CNN Loss vs Accuracy Plot

# %%
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for h in modelhistory:
  modelosses.append(h.history['loss'])
  modeleval_losses.append(h.history['val_loss'])
  modelacc.append(h.history['accuracy'])
  modeleval_acc.append(h.history['val_accuracy'])
modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 5))
ax[0].plot(np.mean(modelosses, axis=0))
ax[0].plot(np.mean(modeleval_losses, axis=0))
ax[0].set_title('LSTM loss')
ax[0].set_ylabel('loss')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'val'], loc='upper right')
ax[1].plot(np.mean(modelacc,axis=0))
ax[1].plot(np.mean(modeleval_acc, axis=0))
ax[1].set_title('LSTM accuracy')
ax[1].set_ylabel('accuracy')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'val'], loc='upper left')
plt.show()
# fig.savefig('lstm_leaveout_patients_loss_and_accuracy.jpg')
