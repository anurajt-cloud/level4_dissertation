# %% [markdown]
# -------------------------------------
# # ECG Beat classification:
# ### Model - LSTM
#
# ### Data Method - Patient hold-out
#
# -------------------------------------

# %% [markdown]
# ### Imports

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import os
import seaborn as sns
from sklearn import *
from sklearn.metrics import *
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import MaxPooling1D

# %%
# from google.colab import drive
# drive.mount('/content/drive')

print("You are using Tensorflow version", tf.__version__)

print(tf.config.list_physical_devices('GPU'))
# Out:
# Mounted at /content/drive

# %%
# path = './drive/MyDrive/Colab_Notebooks/ECG_with_Expected_gradients/'
path = './'

# %%
os.listdir(path)
# Out:
# ['ops.py',
#  'Data',
#  'eager_ops.py',
#  '__pycache__',
#  'example_usage_tf2.ipynb',
#  'Yolas_model.ipynb',
#  'Diagram_creation',
#  'Grid search',
#  'CNN_leaveout_patients_validation.ipynb',
#  'Label_fix',
#  'eval_data',
#  'CNN_leaveout_patients_train_test.ipynb',
#  'CNN_holdout_beats_validation.ipynb',
#  'eval_data_10k',
#  'RAN_MODELS',
#  'LSTM_holdout_beats_validation.ipynb']

# %% [markdown]
# ### Loading data

# %%
# Loading Data
train_c1 = np.genfromtxt(path+'Data/train_beats_sc.csv', delimiter=',')
train_c0 = np.genfromtxt(path+'Data/train_beats_fc.csv', delimiter=',')
test_c1 = np.genfromtxt(path+'Data/test_beats_sc.csv', delimiter=',')
test_c0 = np.genfromtxt(path+'Data/test_beats_fc.csv', delimiter=',')

train_x_c01 = np.concatenate((train_c0[:, :-2], train_c1[:, :-2]), axis=1)
train_y_c01 = np.concatenate((train_c0[:, -2:], train_c1[:, -2:]), axis=1)

test_x_c01 = np.concatenate((test_c0[:, :-2], test_c1[:, :-2]), axis=1)
test_y_c01 = np.concatenate((test_c0[:, -2:], test_c0[:, -2:]), axis=1)

train_x = train_x_c01.reshape(-1, train_x_c01.shape[1], 1).astype('float32')
test_x = test_x_c01.reshape(-1, test_x_c01.shape[1], 1).astype('float32')

train_y = tf.keras.utils.to_categorical(train_y_c01[:,0])
test_y = tf.keras.utils.to_categorical(test_y_c01[:,0])

print("Train:")
print("x:", train_x.shape, "y:", train_y.shape)
print("Test")
print("x:", test_x.shape, "y:", test_y.shape)
# Out:
# Train:
# x: (28984, 920, 1) y: (28984, 9)
# Test
# x: (27219, 920, 1) y: (27219, 9)

# %% [markdown]
# ### Create a performance metrics function

# %%
def showResults(test, pred, model_name):
    accuracy = accuracy_score(test, pred)
    precision= precision_score(test, pred, average='macro')
    recall = recall_score(test, pred, average = 'macro')
    f1score_macro = f1_score(test, pred, average='macro') 
    f1score_micro = f1_score(test, pred, average='micro') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("Recall : {}".format(recall))
    print("f1score macro : {}".format(f1score_macro))
    print("f1score micro : {}".format(f1score_micro))
    cm=confusion_matrix(test, pred, labels=[1,2,3,4,5,6,7,8])
    return (model_name, round(accuracy,3), round(precision,3) , round(recall,3) , round(f1score_macro,3), 
            round(f1score_micro, 3), cm)

# %% [markdown]
# ### Function for building the LSTM model

# %%
verbose, epoch, batch_size = 1, 10, 256
activationFunction='relu'

def getlstmModel():
    
    lstmmodel = Sequential()
    lstmmodel.add(LSTM(128, return_sequences=True, input_shape=(train_x.shape[1],train_x.shape[2])))
    lstmmodel.add(LSTM(9, return_sequences=True))
    lstmmodel.add(MaxPooling1D(pool_size=4,padding='same'))
    lstmmodel.add(Flatten())
    lstmmodel.add(Dense(256, activation=tf.nn.relu))    
    lstmmodel.add(Dense(128, activation=tf.nn.relu))    
    lstmmodel.add(Dense(32, activation=tf.nn.relu))
    lstmmodel.add(Dense(9, activation='softmax'))
    lstmmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    # lstmmodel.summary()
    return lstmmodel
# lstmmodel = getlstmModel()

# lstmhistory= lstmmodel.fit(train_x, train_y, epochs=epoch, verbose=verbose, validation_split=0.2, batch_size = batch_size)
# lstmpredictions = lstmmodel.predict(test_x, verbose=1)

# %% [markdown]
# ### List of models

# %%
lstm1 = getlstmModel()
lstm2 = getlstmModel()
lstm3 = getlstmModel()
lstm4 = getlstmModel()
lstm5 = getlstmModel()
lstm6 = getlstmModel()
lstm7 = getlstmModel()
lstm8 = getlstmModel()
lstm9 = getlstmModel()
lstm10 = getlstmModel()

modellist = [lstm1,lstm2,lstm3,lstm4,lstm5,lstm6,lstm7,lstm8,lstm9,lstm10]

# %% [markdown]
# ### Fitting all the models

# %%
modelhistory = []
for m in range(len(modellist)):
  print("*"*10,"Model",m+1,"*"*10)
  modelhistory.append(modellist[m].fit(train_x, train_y, epochs=epoch, verbose=verbose, validation_split=0.2, batch_size = batch_size))
# Out:
# ********** Model 1 **********
# Epoch 1/10
# 91/91 [==============================] - 41s 358ms/step - loss: 0.4046 - accuracy: 0.8762 - val_loss: 0.0991 - val_accuracy: 0.9655
# Epoch 2/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0726 - accuracy: 0.9779 - val_loss: 0.0771 - val_accuracy: 0.9760
# Epoch 3/10
# 91/91 [==============================] - 31s 339ms/step - loss: 0.0375 - accuracy: 0.9896 - val_loss: 0.0572 - val_accuracy: 0.9829
# Epoch 4/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0251 - accuracy: 0.9936 - val_loss: 0.0434 - val_accuracy: 0.9878
# Epoch 5/10
# 91/91 [==============================] - 30s 335ms/step - loss: 0.0163 - accuracy: 0.9953 - val_loss: 0.0500 - val_accuracy: 0.9871
# Epoch 6/10
# 91/91 [==============================] - 30s 335ms/step - loss: 0.0135 - accuracy: 0.9965 - val_loss: 0.0390 - val_accuracy: 0.9903
# Epoch 7/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.0417 - val_accuracy: 0.9890
# Epoch 8/10
# 91/91 [==============================] - 30s 334ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0414 - val_accuracy: 0.9907
# Epoch 9/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0446 - val_accuracy: 0.9884
# Epoch 10/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0136 - accuracy: 0.9962 - val_loss: 0.0844 - val_accuracy: 0.9807
# ********** Model 2 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 350ms/step - loss: 0.3949 - accuracy: 0.8809 - val_loss: 0.1078 - val_accuracy: 0.9674
# Epoch 2/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0804 - accuracy: 0.9758 - val_loss: 0.0607 - val_accuracy: 0.9834
# Epoch 3/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0442 - accuracy: 0.9873 - val_loss: 0.0614 - val_accuracy: 0.9833
# Epoch 4/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0313 - accuracy: 0.9915 - val_loss: 0.0584 - val_accuracy: 0.9846
# Epoch 5/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0202 - accuracy: 0.9943 - val_loss: 0.0490 - val_accuracy: 0.9859
# Epoch 6/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.0455 - val_accuracy: 0.9888
# Epoch 7/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.0444 - val_accuracy: 0.9872
# Epoch 8/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0497 - val_accuracy: 0.9888
# Epoch 9/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.0363 - val_accuracy: 0.9917
# Epoch 10/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0412 - val_accuracy: 0.9912
# ********** Model 3 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 352ms/step - loss: 0.3788 - accuracy: 0.8794 - val_loss: 0.1152 - val_accuracy: 0.9565
# Epoch 2/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0834 - accuracy: 0.9739 - val_loss: 0.0592 - val_accuracy: 0.9838
# Epoch 3/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0439 - accuracy: 0.9870 - val_loss: 0.0537 - val_accuracy: 0.9840
# Epoch 4/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0303 - accuracy: 0.9914 - val_loss: 0.0573 - val_accuracy: 0.9836
# Epoch 5/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0196 - accuracy: 0.9941 - val_loss: 0.0404 - val_accuracy: 0.9891
# Epoch 6/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.0531 - val_accuracy: 0.9864
# Epoch 7/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.0569 - val_accuracy: 0.9836
# Epoch 8/10
# 91/91 [==============================] - 30s 335ms/step - loss: 0.0210 - accuracy: 0.9940 - val_loss: 0.0595 - val_accuracy: 0.9859
# Epoch 9/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0165 - accuracy: 0.9952 - val_loss: 0.0569 - val_accuracy: 0.9872
# Epoch 10/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.0527 - val_accuracy: 0.9874
# ********** Model 4 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 349ms/step - loss: 0.3919 - accuracy: 0.8771 - val_loss: 0.0893 - val_accuracy: 0.9712
# Epoch 2/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0744 - accuracy: 0.9783 - val_loss: 0.0637 - val_accuracy: 0.9795
# Epoch 3/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0380 - accuracy: 0.9893 - val_loss: 0.0563 - val_accuracy: 0.9812
# Epoch 4/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0261 - accuracy: 0.9927 - val_loss: 0.0558 - val_accuracy: 0.9833
# Epoch 5/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0202 - accuracy: 0.9943 - val_loss: 0.0430 - val_accuracy: 0.9867
# Epoch 6/10
# 91/91 [==============================] - 31s 339ms/step - loss: 0.0148 - accuracy: 0.9956 - val_loss: 0.0418 - val_accuracy: 0.9879
# Epoch 7/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0395 - val_accuracy: 0.9896
# Epoch 8/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0113 - accuracy: 0.9970 - val_loss: 0.0411 - val_accuracy: 0.9884
# Epoch 9/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0450 - val_accuracy: 0.9886
# Epoch 10/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.0400 - val_accuracy: 0.9909
# ********** Model 5 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 348ms/step - loss: 0.3841 - accuracy: 0.8871 - val_loss: 0.1031 - val_accuracy: 0.9695
# Epoch 2/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0736 - accuracy: 0.9782 - val_loss: 0.0743 - val_accuracy: 0.9748
# Epoch 3/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0399 - accuracy: 0.9888 - val_loss: 0.0506 - val_accuracy: 0.9834
# Epoch 4/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0223 - accuracy: 0.9934 - val_loss: 0.0489 - val_accuracy: 0.9840
# Epoch 5/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0178 - accuracy: 0.9956 - val_loss: 0.0465 - val_accuracy: 0.9890
# Epoch 6/10
# 91/91 [==============================] - 30s 335ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0481 - val_accuracy: 0.9846
# Epoch 7/10
# 91/91 [==============================] - 30s 335ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.0408 - val_accuracy: 0.9890
# Epoch 8/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0095 - accuracy: 0.9979 - val_loss: 0.0486 - val_accuracy: 0.9879
# Epoch 9/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0391 - val_accuracy: 0.9902
# Epoch 10/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.0671 - val_accuracy: 0.9822
# ********** Model 6 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 351ms/step - loss: 0.4463 - accuracy: 0.8619 - val_loss: 0.1248 - val_accuracy: 0.9588
# Epoch 2/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0884 - accuracy: 0.9729 - val_loss: 0.0643 - val_accuracy: 0.9819
# Epoch 3/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0441 - accuracy: 0.9881 - val_loss: 0.0508 - val_accuracy: 0.9848
# Epoch 4/10
# 91/91 [==============================] - 31s 339ms/step - loss: 0.0308 - accuracy: 0.9909 - val_loss: 0.0492 - val_accuracy: 0.9867
# Epoch 5/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 0.0455 - val_accuracy: 0.9871
# Epoch 6/10
# 91/91 [==============================] - 31s 339ms/step - loss: 0.0166 - accuracy: 0.9956 - val_loss: 0.0463 - val_accuracy: 0.9872
# Epoch 7/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.0405 - val_accuracy: 0.9907
# Epoch 8/10
# 91/91 [==============================] - 31s 339ms/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.0452 - val_accuracy: 0.9903
# Epoch 9/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0124 - accuracy: 0.9965 - val_loss: 0.0448 - val_accuracy: 0.9883
# Epoch 10/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0122 - accuracy: 0.9968 - val_loss: 0.0375 - val_accuracy: 0.9910
# ********** Model 7 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 350ms/step - loss: 0.3864 - accuracy: 0.8881 - val_loss: 0.1158 - val_accuracy: 0.9660
# Epoch 2/10
# 91/91 [==============================] - 31s 339ms/step - loss: 0.0841 - accuracy: 0.9755 - val_loss: 0.0773 - val_accuracy: 0.9819
# Epoch 3/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0428 - accuracy: 0.9879 - val_loss: 0.0666 - val_accuracy: 0.9769
# Epoch 4/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0282 - accuracy: 0.9917 - val_loss: 0.0430 - val_accuracy: 0.9879
# Epoch 5/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0504 - val_accuracy: 0.9867
# Epoch 6/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.0475 - val_accuracy: 0.9890
# Epoch 7/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0178 - accuracy: 0.9944 - val_loss: 0.0432 - val_accuracy: 0.9893
# Epoch 8/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.0384 - val_accuracy: 0.9898
# Epoch 9/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0090 - accuracy: 0.9976 - val_loss: 0.0515 - val_accuracy: 0.9864
# Epoch 10/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0427 - val_accuracy: 0.9900
# ********** Model 8 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 349ms/step - loss: 0.3544 - accuracy: 0.8930 - val_loss: 0.0896 - val_accuracy: 0.9727
# Epoch 2/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0730 - accuracy: 0.9781 - val_loss: 0.0775 - val_accuracy: 0.9786
# Epoch 3/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0380 - accuracy: 0.9899 - val_loss: 0.0575 - val_accuracy: 0.9845
# Epoch 4/10
# 91/91 [==============================] - 31s 339ms/step - loss: 0.0242 - accuracy: 0.9933 - val_loss: 0.0433 - val_accuracy: 0.9879
# Epoch 5/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0207 - accuracy: 0.9940 - val_loss: 0.0612 - val_accuracy: 0.9841
# Epoch 6/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0164 - accuracy: 0.9953 - val_loss: 0.0516 - val_accuracy: 0.9871
# Epoch 7/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.0408 - val_accuracy: 0.9893
# Epoch 8/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0414 - val_accuracy: 0.9884
# Epoch 9/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0464 - val_accuracy: 0.9893
# Epoch 10/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0402 - val_accuracy: 0.9900
# ********** Model 9 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 350ms/step - loss: 0.3709 - accuracy: 0.8952 - val_loss: 0.1072 - val_accuracy: 0.9708
# Epoch 2/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0773 - accuracy: 0.9762 - val_loss: 0.0603 - val_accuracy: 0.9827
# Epoch 3/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0413 - accuracy: 0.9874 - val_loss: 0.0470 - val_accuracy: 0.9850
# Epoch 4/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0307 - accuracy: 0.9910 - val_loss: 0.0446 - val_accuracy: 0.9860
# Epoch 5/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0187 - accuracy: 0.9944 - val_loss: 0.0419 - val_accuracy: 0.9884
# Epoch 6/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0159 - accuracy: 0.9960 - val_loss: 0.0326 - val_accuracy: 0.9910
# Epoch 7/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 0.0331 - val_accuracy: 0.9914
# Epoch 8/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0174 - accuracy: 0.9952 - val_loss: 0.0394 - val_accuracy: 0.9898
# Epoch 9/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0361 - val_accuracy: 0.9902
# Epoch 10/10
# 91/91 [==============================] - 31s 336ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0368 - val_accuracy: 0.9910
# ********** Model 10 **********
# Epoch 1/10
# 91/91 [==============================] - 36s 350ms/step - loss: 0.3739 - accuracy: 0.8894 - val_loss: 0.1029 - val_accuracy: 0.9681
# Epoch 2/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0807 - accuracy: 0.9752 - val_loss: 0.0772 - val_accuracy: 0.9783
# Epoch 3/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0422 - accuracy: 0.9875 - val_loss: 0.0565 - val_accuracy: 0.9841
# Epoch 4/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0265 - accuracy: 0.9925 - val_loss: 0.0586 - val_accuracy: 0.9827
# Epoch 5/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0208 - accuracy: 0.9938 - val_loss: 0.0535 - val_accuracy: 0.9860
# Epoch 6/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.0509 - val_accuracy: 0.9895
# Epoch 7/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.0489 - val_accuracy: 0.9902
# Epoch 8/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0602 - val_accuracy: 0.9862
# Epoch 9/10
# 91/91 [==============================] - 31s 338ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.0471 - val_accuracy: 0.9902
# Epoch 10/10
# 91/91 [==============================] - 31s 337ms/step - loss: 0.0087 - accuracy: 0.9977 - val_loss: 0.0583 - val_accuracy: 0.9895

# %% [markdown]
# ### Model predictions

# %%
modelpreds = []
for m in range(len(modellist)):
  print("*"*10,"Model",m+1,"*"*10)
  modelpreds.append(np.argmax(modellist[m].predict(test_x, verbose=1),axis=1))
# Out:
# ********** Model 1 **********
# 851/851 [==============================] - 90s 105ms/step
# ********** Model 2 **********
# 851/851 [==============================] - 88s 103ms/step
# ********** Model 3 **********
# 851/851 [==============================] - 90s 105ms/step
# ********** Model 4 **********
# 851/851 [==============================] - 90s 105ms/step
# ********** Model 5 **********
# 851/851 [==============================] - 90s 105ms/step
# ********** Model 6 **********
# 851/851 [==============================] - 86s 100ms/step
# ********** Model 7 **********
# 851/851 [==============================] - 91s 105ms/step
# ********** Model 8 **********
# 851/851 [==============================] - 90s 105ms/step
# ********** Model 9 **********
# 851/851 [==============================] - 90s 105ms/step
# ********** Model 10 **********
# 851/851 [==============================] - 90s 105ms/step

# %% [markdown]
# ### Generating the metrics

# %%
results = []
lstm_actual_value=np.argmax(test_y,axis=1)
for p in range(len(modelpreds)):
  print("*"*10,"Model",p+1,"*"*10)
  results.append(showResults(lstm_actual_value, modelpreds[p],'LSTM'+str(p)))
# Out:
# ********** Model 1 **********
# Accuracy  : 0.9793526580697307
# Precision : 0.8935037986251402
# Recall : 0.9639971295727929
# f1score macro : 0.9230275843158076
# f1score micro : 0.9793526580697307
# ********** Model 2 **********
# Accuracy  : 0.9789852676439252
# Precision : 0.8945719030676447
# Recall : 0.965635762520347
# f1score macro : 0.9262492055409581
# f1score micro : 0.9789852676439252
# ********** Model 3 **********
# Accuracy  : 0.9758624490245784
# Precision : 0.8893592640960588
# Recall : 0.9641585733406767
# f1score macro : 0.9215730869234275
# f1score micro : 0.9758624490245784
# ********** Model 4 **********
# Accuracy  : 0.9760828832800618
# Precision : 0.889960662095551
# Recall : 0.9647047773713524
# f1score macro : 0.9233962249058653
# f1score micro : 0.9760828832800618
# ********** Model 5 **********
# Accuracy  : 0.9473896910246519
# Precision : 0.7819922597462475
# Recall : 0.955916407037056
# f1score macro : 0.8442414965682508
# f1score micro : 0.9473896910246519
# ********** Model 6 **********
# Accuracy  : 0.9769278812594144
# Precision : 0.8917465373755242
# Recall : 0.9628141055866875
# f1score macro : 0.924008527270088
# f1score micro : 0.9769278812594144
# ********** Model 7 **********
# Accuracy  : 0.9711965906168485
# Precision : 0.8639702980310905
# Recall : 0.9688239395603995
# f1score macro : 0.9084567786692986
# f1score micro : 0.9711965906168485
# ********** Model 8 **********
# Accuracy  : 0.9775524449832838
# Precision : 0.8864775594129171
# Recall : 0.9661377553809077
# f1score macro : 0.9213983769697125
# f1score micro : 0.9775524449832838
# ********** Model 9 **********
# Accuracy  : 0.9775891840258643
# Precision : 0.8985615852245228
# Recall : 0.9680151907491756
# f1score macro : 0.9298723121095746
# f1score micro : 0.9775891840258643
# ********** Model 10 **********
# Accuracy  : 0.9755317976413534
# Precision : 0.879389885559976
# Recall : 0.9679879485644206
# f1score macro : 0.9168480580202296
# f1score micro : 0.9755317976413534

# %% [markdown]
# ### Generating the confusion matrices

# %%
cms = []
for p in modelpreds:
  cms.append(confusion_matrix(lstm_actual_value, p, normalize='true'))

# %% [markdown]
# ### Extracting model train and validation accuracy & loss

# %%
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for h in modelhistory:
  modelosses.append(h.history['loss'])
  modeleval_losses.append(h.history['val_loss'])
  modelacc.append(h.history['accuracy'])
  modeleval_acc.append(h.history['val_accuracy'])
modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)
# losses , eval_losses, accuracy, eval_accuracy
history = np.array([modelosses, modeleval_losses, modelacc, modeleval_acc])

# %% [markdown]
# ### Saving the data

# %%
# Saving data LSTM patient leavout
new_path = path+"eval_data_10k/lstm_ph/"

modelpreds = np.array(modelpreds)
results = np.array(results)
cms = np.array(cms)
# modelhistory = np.array(modelhistory)
np.save(new_path+"lstm_modelpreds.npy", modelpreds)
np.save(new_path+"lstm_results.npy", results)
np.save(new_path+"lstm_cms.npy", cms)
np.save(new_path+"lstm_history.npy", history )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses, lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://c519202a-251c-4771-9958-6293a486f425/assets
# INFO:tensorflow:Assets written to: ram://c519202a-251c-4771-9958-6293a486f425/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3317aa650> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe358686e90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn, lstm_cell_23_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://2012816e-f897-464d-8c1c-492e53660998/assets
# INFO:tensorflow:Assets written to: ram://2012816e-f897-464d-8c1c-492e53660998/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3452a3ad0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3452b44d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://c93f75e9-e0b8-46fa-ab40-d6dc09598995/assets
# INFO:tensorflow:Assets written to: ram://c93f75e9-e0b8-46fa-ab40-d6dc09598995/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe33d8b57d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3309edbd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_26_layer_call_fn, lstm_cell_26_layer_call_and_return_conditional_losses, lstm_cell_27_layer_call_fn, lstm_cell_27_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://7d64ab79-3ba6-4805-a757-c910b4fa3561/assets
# INFO:tensorflow:Assets written to: ram://7d64ab79-3ba6-4805-a757-c910b4fa3561/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe349db1f90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe349dbf510> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_28_layer_call_fn, lstm_cell_28_layer_call_and_return_conditional_losses, lstm_cell_29_layer_call_fn, lstm_cell_29_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://e6dc8099-be2f-42d7-a873-a230c593b673/assets
# INFO:tensorflow:Assets written to: ram://e6dc8099-be2f-42d7-a873-a230c593b673/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe33f2836d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe33f25b8d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_30_layer_call_fn, lstm_cell_30_layer_call_and_return_conditional_losses, lstm_cell_31_layer_call_fn, lstm_cell_31_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://57e00367-35c4-4570-bee0-e28b1fa03e83/assets
# INFO:tensorflow:Assets written to: ram://57e00367-35c4-4570-bee0-e28b1fa03e83/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3455bf950> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3455ac790> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_32_layer_call_fn, lstm_cell_32_layer_call_and_return_conditional_losses, lstm_cell_33_layer_call_fn, lstm_cell_33_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://ec7099be-2eb9-437f-9066-af2d8790e06f/assets
# INFO:tensorflow:Assets written to: ram://ec7099be-2eb9-437f-9066-af2d8790e06f/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3740883d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe35896a3d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_34_layer_call_fn, lstm_cell_34_layer_call_and_return_conditional_losses, lstm_cell_35_layer_call_fn, lstm_cell_35_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://15f6d886-187c-4e58-bff1-034d47de8d40/assets
# INFO:tensorflow:Assets written to: ram://15f6d886-187c-4e58-bff1-034d47de8d40/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe33fcb0690> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe358415690> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_36_layer_call_fn, lstm_cell_36_layer_call_and_return_conditional_losses, lstm_cell_37_layer_call_fn, lstm_cell_37_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://864214ff-efd3-4467-a719-bb413ec6f106/assets
# INFO:tensorflow:Assets written to: ram://864214ff-efd3-4467-a719-bb413ec6f106/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe3582fbe50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe349ef50d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_38_layer_call_fn, lstm_cell_38_layer_call_and_return_conditional_losses, lstm_cell_39_layer_call_fn, lstm_cell_39_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://d4712763-9c70-4f93-b077-c495104dc2ad/assets
# INFO:tensorflow:Assets written to: ram://d4712763-9c70-4f93-b077-c495104dc2ad/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe349e7ce10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe349e692d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# ### Visualising the Mean Confusion Matrix

# %%
categories=['N','L','R','V','A','F','f','/']
cm = np.mean(cms, axis=0)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, xticklabels=categories, yticklabels=categories)
plt.title('LSTM - 10k Mean Confusion Matrix')
# plt.savefig("lstm_mean_cm_pl.png", dpi=300)
plt.show()

# %% [markdown]
# ### Mean Metrics

# %%
metrics = ["Accuracy", "Precision", "Recall", "f1-score macro", "f1-score micro"]
mean_metrics = np.mean(results[:,1:6], axis=0)
for i in range(len(mean_metrics)):
  print(metrics[i],":",mean_metrics[i])
# Out:
# Accuracy : 0.9737000000000002
# Precision : 0.877
# Recall : 0.9649000000000001
# f1-score macro : 0.9138000000000002
# f1-score micro : 0.9737000000000002

# %% [markdown]
# ### Mean LSTM Loss vs Accuracy Plot

# %%
# Save the model so we can visualize it with Netron (https://github.com/lutzroeder/netron):
# tf.keras.models.save_model(lstmmodel, 'lstmmodel_module2.h5')
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for h in modelhistory:
  modelosses.append(h.history['loss'])
  modeleval_losses.append(h.history['val_loss'])
  modelacc.append(h.history['accuracy'])
  modeleval_acc.append(h.history['val_accuracy'])
modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 5))
ax[0].plot(np.mean(modelosses, axis=0))
ax[0].plot(np.mean(modeleval_losses, axis=0))
ax[0].set_title('LSTM loss')
ax[0].set_ylabel('loss')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'val'], loc='upper right')
ax[1].plot(np.mean(modelacc,axis=0))
ax[1].plot(np.mean(modeleval_acc, axis=0))
ax[1].set_title('LSTM accuracy')
ax[1].set_ylabel('accuracy')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'val'], loc='upper left')
plt.show()
# fig.savefig('lstm_leaveout_patients_loss_and_accuracy.jpg')
