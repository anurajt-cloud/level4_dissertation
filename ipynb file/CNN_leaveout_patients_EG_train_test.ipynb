# %% [markdown]
# -------------------------------------
# # ECG Beat classification:
# ### Model - CNN
#
# ### Data Method - Patient leave-out
#
# -------------------------------------

# %% [markdown]
# ### Imports

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import os
import seaborn as sns
from sklearn import *
from sklearn.metrics import *
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D, LeakyReLU
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Add
from tensorflow.keras.layers import Activation
import itertools
import time
from sklearn.utils import resample
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import ECG.eager_ops
from ECG import eager_ops
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from sklearn.model_selection import train_test_split

# %%
# from google.colab import drive
# drive.mount('/content/drive')
print("You are using Tensorflow version", tf.__version__)

print(tf.config.list_physical_devices('GPU'))
# Out:
# You are using Tensorflow version 2.1.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# path = './drive/MyDrive/Colab_Notebooks/ECG_with_Expected_gradients/'
path = './'

# %%
os.listdir(path)
# Out:
# ['CNN_leaveout_patients_validation.ipynb',
#  'Data',
#  'ECG',
#  'eval_data_10k',
#  'RAN_MODELS']

# %% [markdown]
# ### Loading data

# %%
train_c1 = np.genfromtxt(path+'Data/train_patients_sc.csv', delimiter=',')
train_c0 = np.genfromtxt(path+'Data/train_patients_fc.csv', delimiter=',')
test_c1 = np.genfromtxt(path+'Data/test_patients_sc.csv', delimiter=',')
test_c0 = np.genfromtxt(path+'Data/test_patients_fc.csv', delimiter=',')

train_x_c01 = np.concatenate((train_c0[:, :-2], train_c1[:, :-2]), axis=1)
train_y_c01 = np.concatenate((train_c0[:, -2:], train_c1[:, -2:]), axis=1)

test_x_c01 = np.concatenate((test_c0[:, :-2], test_c1[:, :-2]), axis=1)
test_y_c01 = np.concatenate((test_c0[:, -2:], test_c0[:, -2:]), axis=1)

train_x = train_x_c01.reshape(-1, train_x_c01.shape[1], 1).astype('float32')
test_x = test_x_c01.reshape(-1, test_x_c01.shape[1], 1).astype('float32')

train_y = tf.keras.utils.to_categorical(train_y_c01[:,0])
test_y = tf.keras.utils.to_categorical(test_y_c01[:,0])

print("Train:")
print("x:", train_x.shape, "y:", train_y.shape)
print("Test")
print("x:", test_x.shape, "y:", test_y.shape)
# Out:
# Train:
# x: (32048, 920, 1) y: (32048, 9)
# Test
# x: (9902, 920, 1) y: (9902, 9)

# %% [markdown]
# ### Creating a performance metrics function

# %%
def showResults(test, pred, model_name):
    accuracy = accuracy_score(test, pred)
    precision= precision_score(test, pred, average='macro')
    recall = recall_score(test, pred, average = 'macro')
    f1score_macro = f1_score(test, pred, average='macro') 
    f1score_micro = f1_score(test, pred, average='micro') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("Recall : {}".format(recall))
    print("f1score macro : {}".format(f1score_macro))
    print("f1score micro : {}".format(f1score_micro))
    cm=confusion_matrix(test, pred, labels=[1,2,3,4,5,6,7,8])
    return (model_name, round(accuracy,3), round(precision,3) , round(recall,3) , round(f1score_macro,3), 
            round(f1score_micro, 3), cm)

# %% [markdown]
# ### Function for building the CNN model

# %%
opt = Adam(learning_rate=0.001)

def getCNNModel():
    
    input = keras.layers.Input(shape=(train_x.shape[1],train_x.shape[2]))
    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)

    #block 2

    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)
    x = keras.layers.Dropout(0.2)(x)

    #block 3
    for i in range(4):


        shortcut = MaxPooling1D(pool_size=1)(x)

        filters = 64 * ((i//2)+1)
        # print("Filter size = "+str(filters))
        x = keras.layers.Conv1D(kernel_size=16, filters=filters, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.LeakyReLU(alpha=0.3)(x)

        x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)

        x = keras.layers.LeakyReLU(alpha=0.3)(x)
        x = keras.layers.Dropout(0.2)(x)
    

        x = tf.keras.layers.Add()([x, shortcut])


    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)
    x = keras.layers.Flatten()(x)
    out = keras.layers.Dense(9, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=[input], outputs=out)
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    return model

# %% [markdown]
# ### List of models

# %%
cnn1 = getCNNModel()
cnn2 = getCNNModel()
cnn3 = getCNNModel()
cnn4 = getCNNModel()
cnn5 = getCNNModel()
cnn6 = getCNNModel()
cnn7 = getCNNModel()
cnn8 = getCNNModel()
cnn9 = getCNNModel()
cnn10 = getCNNModel()

modellist = [cnn1, cnn2, cnn3, cnn4, cnn5, cnn6, cnn7, cnn8, cnn9, cnn10]

# %% [markdown]
# ### Defining training functions and parameters

# %%
lamb = 0.0001
num_epochs = 10
batch_size = 50
optimizer = tf.optimizers.Adam(learning_rate = 0.0001)
loss_fn = tf.keras.losses.CategoricalCrossentropy()
val_loss_fn = tf.keras.losses.CategoricalCrossentropy()
train_acc_fn = tf.keras.metrics.CategoricalAccuracy()
val_acc_fn = tf.keras.metrics.CategoricalAccuracy()
test_acc_fn = tf.keras.metrics.CategoricalAccuracy()

# %%
#train step
def train_step(model_m, inputs, labels):
    with tf.GradientTape() as tape:
        tape.watch(tf.convert_to_tensor(inputs))
        predictions = model_m(inputs, training=True)
        pred_loss = loss_fn(labels, predictions)
        total_loss = pred_loss

        if len(model_m.losses) > 0:
            regularization_loss = tf.math.add_n(model_m.losses)
            total_loss = total_loss + regularization_loss

        attributions = eager_ops.expected_gradients(inputs, labels, model_m)

        summed_attributions = tf.reduce_sum(attributions, axis=-1, keepdims=True)

        normalized_attributions = tf.image.per_image_standardization(summed_attributions)

        attribution_loss = lamb * tf.reduce_mean(tf.image.total_variation(normalized_attributions))

        total_loss+= attribution_loss
    
    gradients = tape.gradient(total_loss, model_m.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model_m.trainable_variables))
    return predictions,total_loss

# %%
# function to train a model
def training(model):
    training_acc = []
    training_loss = []
    validation_acc = []
    validation_loss = []

    start_time = time.time()
    for epoch in range(num_epochs):
        indices = np.random.permutation(len(train_x))
        # train validaion split
        train_indices, val_indices = train_test_split(indices, test_size=0.2, stratify=train_y[indices])
        # extracting the training set
        new_train_x = train_x[train_indices]
        new_train_y = train_y[train_indices]
        # generating indices for training batches
        new_indices = np.random.permutation(len(new_train_x))
        # extracting the validation set
        val_x = train_x[val_indices]
        val_y = train_y[val_indices]
        

        for i in range(0, len(new_train_x), batch_size):
            x_batch_train = new_train_x[new_indices[i:min(i + batch_size, len(new_train_x))]]
            y_batch_train = new_train_y[new_indices[i:min(i + batch_size, len(new_train_y))]]

            predictions,epoch_loss = train_step(model, x_batch_train, y_batch_train)

            train_acc_fn(y_batch_train, predictions)

        train_acc = train_acc_fn.result().numpy()

        # validating
        val_preds = model.predict(val_x)
        val_acc_fn(val_y, val_preds)
        val_loss = val_loss_fn(val_y, val_preds).numpy()

        # appending training loss and acc
        training_acc.append(train_acc)
        training_loss.append(epoch_loss.numpy())
        # appending validation loss and acc
        validation_acc.append(val_acc_fn.result().numpy())
        validation_loss.append(val_loss)

        print('Epoch {} - train_accuracy: {:.4f}, train_loss: {:.4f} | val_accuracy: {:.4f}, val_loss: {:.4f} ({:.1f} seconds / epoch)'.format(epoch + 1, train_acc, epoch_loss, val_acc_fn.result().numpy(), val_loss, time.time()-start_time))

        start_time = time.time()
        train_acc_fn.reset_states()
        val_acc_fn.reset_states()
    return training_loss, validation_loss, training_acc, validation_acc

# %% [markdown]
# ### Fitting all the models

# %%
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for m in range(len(modellist)):
    print("*"*10,"Model",m+1,"*"*10)
    tl, vl, ta, va = training(modellist[m])
    modelosses.append(tl)
    modeleval_losses.append(vl)
    modelacc.append(ta)
    modeleval_acc.append(va)

modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)
# losses , eval_losses, accuracy, eval_accuracy
history = np.array([modelosses, modeleval_losses, modelacc, modeleval_acc])
# Out:
# ********** Model 1 **********
# Epoch 1 - train_accuracy: 0.7799, train_loss: 1.6535 | val_accuracy: 0.8457, val_loss: 0.6845 (91.0 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9015, train_loss: 0.8931 | val_accuracy: 0.9239, val_loss: 0.3432 (84.7 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9131, train_loss: 1.0207 | val_accuracy: 0.9276, val_loss: 0.2950 (85.3 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9223, train_loss: 0.5009 | val_accuracy: 0.9415, val_loss: 0.2581 (86.6 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9291, train_loss: 1.1240 | val_accuracy: 0.9365, val_loss: 0.2922 (85.1 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9292, train_loss: 0.9180 | val_accuracy: 0.9362, val_loss: 0.3132 (85.3 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9344, train_loss: 0.7116 | val_accuracy: 0.9342, val_loss: 0.3802 (85.4 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9360, train_loss: 1.3327 | val_accuracy: 0.9418, val_loss: 0.3283 (85.9 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9343, train_loss: 0.9150 | val_accuracy: 0.9399, val_loss: 0.2903 (86.6 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9388, train_loss: 1.5532 | val_accuracy: 0.9382, val_loss: 0.3362 (86.5 seconds / epoch)
# ********** Model 2 **********
# Epoch 1 - train_accuracy: 0.8415, train_loss: 1.2137 | val_accuracy: 0.8872, val_loss: 0.6307 (91.4 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9076, train_loss: 1.2831 | val_accuracy: 0.9314, val_loss: 0.3820 (85.0 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9157, train_loss: 1.0786 | val_accuracy: 0.9354, val_loss: 0.3785 (85.4 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9294, train_loss: 0.9665 | val_accuracy: 0.9371, val_loss: 0.3744 (85.2 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9346, train_loss: 0.5593 | val_accuracy: 0.9254, val_loss: 0.4101 (85.2 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9312, train_loss: 0.7036 | val_accuracy: 0.9401, val_loss: 0.3287 (85.4 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9322, train_loss: 0.5456 | val_accuracy: 0.9421, val_loss: 0.3321 (85.5 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9392, train_loss: 0.9009 | val_accuracy: 0.9424, val_loss: 0.3220 (85.6 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9362, train_loss: 0.9195 | val_accuracy: 0.9370, val_loss: 0.3490 (85.8 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9388, train_loss: 0.6798 | val_accuracy: 0.9496, val_loss: 0.2929 (86.4 seconds / epoch)
# ********** Model 3 **********
# Epoch 1 - train_accuracy: 0.8519, train_loss: 1.1430 | val_accuracy: 0.9309, val_loss: 0.4263 (91.4 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9130, train_loss: 1.1951 | val_accuracy: 0.9259, val_loss: 0.4914 (86.3 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9239, train_loss: 0.8361 | val_accuracy: 0.9290, val_loss: 0.3993 (85.2 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9320, train_loss: 1.0440 | val_accuracy: 0.9193, val_loss: 0.5608 (85.1 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9280, train_loss: 0.6852 | val_accuracy: 0.9423, val_loss: 0.3583 (85.3 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9300, train_loss: 1.0128 | val_accuracy: 0.9320, val_loss: 0.4092 (85.2 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9354, train_loss: 0.4717 | val_accuracy: 0.9457, val_loss: 0.3813 (85.3 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9348, train_loss: 1.0506 | val_accuracy: 0.9384, val_loss: 0.3593 (85.0 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9371, train_loss: 1.3572 | val_accuracy: 0.9459, val_loss: 0.3797 (84.9 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9276, train_loss: 0.9037 | val_accuracy: 0.9460, val_loss: 0.3470 (84.9 seconds / epoch)
# ********** Model 4 **********
# Epoch 1 - train_accuracy: 0.8539, train_loss: 1.2851 | val_accuracy: 0.9183, val_loss: 0.5317 (91.2 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9201, train_loss: 1.2725 | val_accuracy: 0.9128, val_loss: 0.4857 (84.9 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9234, train_loss: 0.8641 | val_accuracy: 0.9407, val_loss: 0.3877 (84.7 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9260, train_loss: 0.5049 | val_accuracy: 0.9398, val_loss: 0.3840 (84.1 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9338, train_loss: 0.7241 | val_accuracy: 0.9538, val_loss: 0.2764 (84.0 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9363, train_loss: 0.5509 | val_accuracy: 0.9317, val_loss: 0.3618 (85.5 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9376, train_loss: 0.3243 | val_accuracy: 0.9502, val_loss: 0.3169 (85.4 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9390, train_loss: 0.6007 | val_accuracy: 0.9368, val_loss: 0.4242 (85.7 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9389, train_loss: 1.3936 | val_accuracy: 0.9401, val_loss: 0.3540 (85.2 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9393, train_loss: 0.8373 | val_accuracy: 0.9378, val_loss: 0.3893 (85.6 seconds / epoch)
# ********** Model 5 **********
# Epoch 1 - train_accuracy: 0.8662, train_loss: 1.0186 | val_accuracy: 0.9200, val_loss: 0.4736 (91.8 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9192, train_loss: 1.0188 | val_accuracy: 0.9265, val_loss: 0.4059 (85.2 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9238, train_loss: 0.7597 | val_accuracy: 0.9315, val_loss: 0.4034 (85.3 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9247, train_loss: 1.3229 | val_accuracy: 0.9126, val_loss: 0.5675 (85.2 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9346, train_loss: 0.7802 | val_accuracy: 0.9440, val_loss: 0.3731 (85.2 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9357, train_loss: 1.2845 | val_accuracy: 0.9477, val_loss: 0.3596 (85.1 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9376, train_loss: 0.9425 | val_accuracy: 0.9465, val_loss: 0.3679 (85.2 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9419, train_loss: 0.4504 | val_accuracy: 0.9527, val_loss: 0.3222 (85.5 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9437, train_loss: 1.4565 | val_accuracy: 0.9382, val_loss: 0.3831 (85.2 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9415, train_loss: 0.9597 | val_accuracy: 0.9557, val_loss: 0.3141 (85.3 seconds / epoch)
# ********** Model 6 **********
# Epoch 1 - train_accuracy: 0.8660, train_loss: 1.9901 | val_accuracy: 0.9100, val_loss: 0.4867 (90.6 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9191, train_loss: 0.2270 | val_accuracy: 0.9320, val_loss: 0.4230 (85.2 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9296, train_loss: 1.2740 | val_accuracy: 0.9296, val_loss: 0.3874 (85.0 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9315, train_loss: 1.7821 | val_accuracy: 0.9284, val_loss: 0.4496 (85.1 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9393, train_loss: 0.7741 | val_accuracy: 0.9563, val_loss: 0.2819 (85.2 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9402, train_loss: 0.6287 | val_accuracy: 0.9183, val_loss: 0.5256 (86.1 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9402, train_loss: 0.8227 | val_accuracy: 0.9460, val_loss: 0.3387 (85.3 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9431, train_loss: 2.3699 | val_accuracy: 0.9424, val_loss: 0.4011 (85.2 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9408, train_loss: 0.9996 | val_accuracy: 0.9321, val_loss: 0.4596 (85.1 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9434, train_loss: 0.5985 | val_accuracy: 0.9523, val_loss: 0.3285 (85.6 seconds / epoch)
# ********** Model 7 **********
# Epoch 1 - train_accuracy: 0.8486, train_loss: 1.6360 | val_accuracy: 0.8668, val_loss: 0.8164 (90.7 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9112, train_loss: 0.9559 | val_accuracy: 0.9147, val_loss: 0.4649 (84.9 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9201, train_loss: 0.7197 | val_accuracy: 0.9402, val_loss: 0.3329 (85.5 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9253, train_loss: 1.4082 | val_accuracy: 0.9449, val_loss: 0.3724 (83.7 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9328, train_loss: 0.8009 | val_accuracy: 0.9390, val_loss: 0.3946 (83.6 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9402, train_loss: 1.7289 | val_accuracy: 0.9251, val_loss: 0.4604 (83.1 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9395, train_loss: 0.8860 | val_accuracy: 0.9367, val_loss: 0.3940 (84.5 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9370, train_loss: 2.2433 | val_accuracy: 0.9463, val_loss: 0.3480 (84.6 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9405, train_loss: 0.9714 | val_accuracy: 0.9376, val_loss: 0.3877 (84.0 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9376, train_loss: 1.9495 | val_accuracy: 0.8758, val_loss: 0.8733 (84.0 seconds / epoch)
# ********** Model 8 **********
# Epoch 1 - train_accuracy: 0.8711, train_loss: 0.6660 | val_accuracy: 0.8680, val_loss: 0.7284 (90.5 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9141, train_loss: 1.2305 | val_accuracy: 0.9356, val_loss: 0.3888 (84.4 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9299, train_loss: 1.0254 | val_accuracy: 0.9231, val_loss: 0.5056 (84.4 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9298, train_loss: 0.6969 | val_accuracy: 0.9395, val_loss: 0.3306 (84.4 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9393, train_loss: 0.5699 | val_accuracy: 0.9440, val_loss: 0.3305 (84.3 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9402, train_loss: 0.9530 | val_accuracy: 0.9454, val_loss: 0.3451 (84.2 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9448, train_loss: 1.1053 | val_accuracy: 0.9554, val_loss: 0.2907 (85.3 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9436, train_loss: 0.5755 | val_accuracy: 0.9426, val_loss: 0.3713 (84.3 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9389, train_loss: 0.6885 | val_accuracy: 0.9502, val_loss: 0.3414 (84.6 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9453, train_loss: 1.2037 | val_accuracy: 0.9515, val_loss: 0.3529 (83.2 seconds / epoch)
# ********** Model 9 **********
# Epoch 1 - train_accuracy: 0.8392, train_loss: 0.5851 | val_accuracy: 0.9095, val_loss: 0.4834 (89.3 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9072, train_loss: 1.6456 | val_accuracy: 0.9145, val_loss: 0.5507 (83.7 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9191, train_loss: 1.5146 | val_accuracy: 0.9300, val_loss: 0.3577 (83.4 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9243, train_loss: 1.2000 | val_accuracy: 0.9275, val_loss: 0.4009 (83.6 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9346, train_loss: 1.6536 | val_accuracy: 0.9376, val_loss: 0.3126 (83.7 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9260, train_loss: 0.7176 | val_accuracy: 0.9232, val_loss: 0.4133 (84.0 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9327, train_loss: 0.8448 | val_accuracy: 0.9245, val_loss: 0.3887 (84.3 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9307, train_loss: 1.3293 | val_accuracy: 0.9454, val_loss: 0.3343 (82.6 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9414, train_loss: 0.9182 | val_accuracy: 0.9563, val_loss: 0.2578 (82.1 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9423, train_loss: 0.7508 | val_accuracy: 0.9521, val_loss: 0.2857 (82.1 seconds / epoch)
# ********** Model 10 **********
# Epoch 1 - train_accuracy: 0.8510, train_loss: 1.2628 | val_accuracy: 0.9019, val_loss: 0.6011 (88.9 seconds / epoch)
# Epoch 2 - train_accuracy: 0.9140, train_loss: 1.2441 | val_accuracy: 0.9324, val_loss: 0.5122 (82.1 seconds / epoch)
# Epoch 3 - train_accuracy: 0.9228, train_loss: 1.0488 | val_accuracy: 0.9370, val_loss: 0.4444 (82.3 seconds / epoch)
# Epoch 4 - train_accuracy: 0.9315, train_loss: 1.4236 | val_accuracy: 0.9371, val_loss: 0.4039 (82.2 seconds / epoch)
# Epoch 5 - train_accuracy: 0.9341, train_loss: 0.8451 | val_accuracy: 0.9401, val_loss: 0.4173 (82.3 seconds / epoch)
# Epoch 6 - train_accuracy: 0.9420, train_loss: 0.9912 | val_accuracy: 0.9527, val_loss: 0.3341 (83.2 seconds / epoch)
# Epoch 7 - train_accuracy: 0.9441, train_loss: 0.9723 | val_accuracy: 0.9451, val_loss: 0.3860 (82.2 seconds / epoch)
# Epoch 8 - train_accuracy: 0.9391, train_loss: 0.7650 | val_accuracy: 0.9429, val_loss: 0.3957 (82.4 seconds / epoch)
# Epoch 9 - train_accuracy: 0.9395, train_loss: 1.1540 | val_accuracy: 0.9443, val_loss: 0.3909 (82.4 seconds / epoch)
# Epoch 10 - train_accuracy: 0.9419, train_loss: 0.9378 | val_accuracy: 0.9510, val_loss: 0.3620 (84.0 seconds / epoch)

# %% [markdown]
# ### Model predictions

# %%
modelpreds = []
for m in range(len(modellist)):
  print("*"*10, "Model", m+1, "*"*10)
  modelpreds.append(np.argmax(modellist[m].predict(test_x, verbose=1),axis=1))
# Out:
# ********** Model 1 **********
# 9902/9902 [==============================] - 3s 274us/sample
# ********** Model 2 **********
# 9902/9902 [==============================] - 2s 236us/sample
# ********** Model 3 **********
# 9902/9902 [==============================] - 2s 240us/sample
# ********** Model 4 **********
# 9902/9902 [==============================] - 2s 240us/sample
# ********** Model 5 **********
# 9902/9902 [==============================] - 2s 238us/sample
# ********** Model 6 **********
# 9902/9902 [==============================] - 2s 236us/sample
# ********** Model 7 **********
# 9902/9902 [==============================] - 2s 237us/sample
# ********** Model 8 **********
# 9902/9902 [==============================] - 2s 239us/sample
# ********** Model 9 **********
# 9902/9902 [==============================] - 2s 240us/sample
# ********** Model 10 **********
# 9902/9902 [==============================] - 2s 236us/sample

# %% [markdown]
# ### Generating the metrics

# %%
results = []
cnn_actual_value=np.argmax(test_y,axis=1)
for p in range(len(modelpreds)):
  print("*"*10,"Model",p+1,"*"*10)
  results.append(showResults(cnn_actual_value, modelpreds[p],'CNN'+str(p)))
# Out:
# ********** Model 1 **********
# Accuracy  : 0.8254898000403958
# Precision : 0.4549236901244308
# Recall : 0.4815528215708471
# f1score macro : 0.4618396743423386
# f1score micro : 0.8254898000403958
# ********** Model 2 **********
# Accuracy  : 0.8111492627751969
# Precision : 0.4105012783681996
# Recall : 0.46169672909249737
# f1score macro : 0.42463167857470285
# f1score micro : 0.8111492627751969
# ********** Model 3 **********
# Accuracy  : 0.8004443546758231
# Precision : 0.42461832924987586
# Recall : 0.4768774944799412
# f1score macro : 0.4402503771994629
# f1score micro : 0.8004443546758231
# ********** Model 4 **********
# Accuracy  : 0.8135730155524137
# Precision : 0.4056197517940098
# Recall : 0.4848348703658786
# f1score macro : 0.42613196067743364
# f1score micro : 0.8135730155524137
# ********** Model 5 **********
# Accuracy  : 0.8203393253888104
# Precision : 0.4265201659185536
# Recall : 0.48210960648405765
# f1score macro : 0.43266907135442656
# f1score micro : 0.8203393253888103
# ********** Model 6 **********
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy  : 0.8259947485356494
# Precision : 0.43714560365132293
# Recall : 0.48750445311319546
# f1score macro : 0.43311673531408557
# f1score micro : 0.8259947485356494
# ********** Model 7 **********
# Accuracy  : 0.7882246010906887
# Precision : 0.4481666255275686
# Recall : 0.4595875336320535
# f1score macro : 0.45290574815552864
# f1score micro : 0.7882246010906888
# ********** Model 8 **********
# Accuracy  : 0.8260957382347001
# Precision : 0.49359152391204725
# Recall : 0.489389528054228
# f1score macro : 0.4798457888795109
# f1score micro : 0.8260957382347001
# ********** Model 9 **********
# Accuracy  : 0.8097354069884872
# Precision : 0.40688188362523187
# Recall : 0.46518694311671593
# f1score macro : 0.4204237490138318
# f1score micro : 0.8097354069884872
# ********** Model 10 **********
# Accuracy  : 0.8010502928701273
# Precision : 0.47012887185500973
# Recall : 0.4585866540721341
# f1score macro : 0.4642480460852154
# f1score micro : 0.8010502928701274
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Generating the confusion matrices

# %%
cms = []
for p in modelpreds:
  cms.append(confusion_matrix(cnn_actual_value, p, normalize='true'))

# %% [markdown]
# ### Saving the data

# %%
# Saving data LSTM patient leavout
new_path = path+"eval_data_10k/cnn_pl_eg/"

modelpreds = np.array(modelpreds)
results = np.array(results)
cms = np.array(cms)
# modelhistory = np.array(modelhistory)
np.save(new_path+"cnn_modelpreds.npy", modelpreds)
np.save(new_path+"cnn_results.npy", results)
np.save(new_path+"cnn_cms.npy", cms)
np.save(new_path+"cnn_history.npy", history)
# Out:
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """

# %%
metrics = ["Accuracy", "Precision", "Recall", "f1-score macro", "f1-score micro"]
mean_metrics = np.mean(results[:,1:6], axis=0)
for i in range(len(mean_metrics)):
  print(metrics[i],":",mean_metrics[i])
# Out:
# Accuracy : 0.8121
# Precision : 0.438
# Recall : 0.4749
# f1-score macro : 0.4436
# f1-score micro : 0.8121

# %%
categories=['N','L','R','V','A','F','f','/']
cm = np.mean(cms, axis=0)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, xticklabels=categories, yticklabels=categories)
plt.title('CNN - 10k Mean Confusion Matrix')
# plt.savefig("lstm_mean_cm_pl.png", dpi=300)
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 5))
ax[0].plot(np.mean(modelosses, axis=0))
ax[0].plot(np.mean(modeleval_losses, axis=0))
ax[0].set_title('CNN loss')
ax[0].set_ylabel('loss')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'val'], loc='upper right')
ax[1].plot(np.mean(modelacc,axis=0))
ax[1].plot(np.mean(modeleval_acc, axis=0))
ax[1].set_title('CNN accuracy')
ax[1].set_ylabel('accuracy')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'val'], loc='upper left')
plt.show()
# fig.savefig('lstm_leaveout_patients_loss_and_accuracy.jpg')

# %% [markdown]
# ### Extra

# %%
# def gini_coefficient(x):
#     """Compute Gini coefficient of array of values"""
#     diffsum = 0
#     for i, xi in enumerate(x[:-1], 1):
#         diffsum += np.sum(np.abs(xi - x[i:]))
#     return diffsum / (len(x)**2 * np.mean(x))

# %%
# input = keras.layers.Input(shape=(train_x.shape[1],train_x.shape[2]))
# x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(input)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.LeakyReLU(alpha=0.3)(x)

# #block 2

# x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.LeakyReLU(alpha=0.3)(x)
# x = keras.layers.Dropout(0.2)(x)

# #block 3
# for i in range(4):


#     shortcut = MaxPooling1D(pool_size=1)(x)

#     filters = 64 * ((i//2)+1)
#     print("Filter size = "+str(filters))
#     x = keras.layers.Conv1D(kernel_size=16, filters=filters, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)
#     x = keras.layers.BatchNormalization()(x)
#     x = keras.layers.LeakyReLU(alpha=0.3)(x)

#     x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)

#     x = keras.layers.LeakyReLU(alpha=0.3)(x)
#     x = keras.layers.Dropout(0.2)(x)
 

#     x = tf.keras.layers.Add()([x, shortcut])


# x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
# x = keras.layers.BatchNormalization()(x)
# x = keras.layers.LeakyReLU(alpha=0.3)(x)
# x = keras.layers.Flatten()(x)
# out = keras.layers.Dense(9, activation='softmax')(x)
# model = tf.keras.models.Model(inputs=[input], outputs=out)
