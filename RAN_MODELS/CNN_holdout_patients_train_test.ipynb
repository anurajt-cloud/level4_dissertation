# %% [markdown]
# -------------------------------------
# # ECG Beat classification:
# ### Model - CNN
#
# ### Data Method - Patient hold-out
#
# -------------------------------------

# %% [markdown]
# ### Imports

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import os
import seaborn as sns
from sklearn import *
from sklearn.metrics import *
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D, LeakyReLU
from sklearn.utils import shuffle
from tensorflow import keras
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Add
from tensorflow.keras.layers import Activation
import itertools
import time
from sklearn.utils import resample
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# from google.colab import drive
# drive.mount('/content/drive')

print("You are using Tensorflow version", tf.__version__)

print(tf.config.list_physical_devices('GPU'))
# Out:
# You are using Tensorflow version 2.1.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# path = './drive/MyDrive/Colab_Notebooks/ECG_with_Expected_gradients/'
path = './'

# %%
os.listdir(path)
# Out:
# ['CNN_holdout_patients_train_test.ipynb',
#  'Data',
#  'ECG',
#  'eval_data_10k',
#  'RAN_MODELS',
#  'reserver_eval_data',
#  'tryCNN_holdout_patients_IG_train_test.ipynb',
#  'tryLSTM_leaveout_patients_EG_train_test.ipynb']

# %% [markdown]
# ### Loading data

# %%
train_c1 = np.genfromtxt(path+'Data/train_beats_sc.csv', delimiter=',')
train_c0 = np.genfromtxt(path+'Data/train_beats_fc.csv', delimiter=',')
test_c1 = np.genfromtxt(path+'Data/test_beats_sc.csv', delimiter=',')
test_c0 = np.genfromtxt(path+'Data/test_beats_fc.csv', delimiter=',')

train_x_c01 = np.concatenate((train_c0[:, :-2], train_c1[:, :-2]), axis=1)
train_y_c01 = np.concatenate((train_c0[:, -2:], train_c1[:, -2:]), axis=1)

test_x_c01 = np.concatenate((test_c0[:, :-2], test_c1[:, :-2]), axis=1)
test_y_c01 = np.concatenate((test_c0[:, -2:], test_c0[:, -2:]), axis=1)

train_x = train_x_c01.reshape(-1, train_x_c01.shape[1], 1).astype('float32')
test_x = test_x_c01.reshape(-1, test_x_c01.shape[1], 1).astype('float32')

train_y = tf.keras.utils.to_categorical(train_y_c01[:,0])
test_y = tf.keras.utils.to_categorical(test_y_c01[:,0])

print("Train:")
print("x:", train_x.shape, "y:", train_y.shape)
print("Test")
print("x:", test_x.shape, "y:", test_y.shape)
# Out:
# Train:
# x: (28984, 920, 1) y: (28984, 9)
# Test
# x: (27219, 920, 1) y: (27219, 9)

# %% [markdown]
# ### Creating a performance metrics function

# %%
def showResults(test, pred, model_name):
    accuracy = accuracy_score(test, pred)
    precision= precision_score(test, pred, average='macro')
    recall = recall_score(test, pred, average = 'macro')
    f1score_macro = f1_score(test, pred, average='macro') 
    f1score_micro = f1_score(test, pred, average='micro') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("Recall : {}".format(recall))
    print("f1score macro : {}".format(f1score_macro))
    print("f1score micro : {}".format(f1score_micro))
    cm=confusion_matrix(test, pred, labels=[1,2,3,4,5,6,7,8])
    return (model_name, round(accuracy,3), round(precision,3) , round(recall,3) , round(f1score_macro,3), 
            round(f1score_micro, 3), cm)

# %% [markdown]
# ### Function for building the CNN model

# %%
# Defining the model
verbose = 1
epochs = 10
batch_size = 50

opt = Adam(learning_rate=0.0001)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
        factor=0.1,
        patience=2,
        min_lr=0.0001 * 0.0001)

def getCNNModel():
    
    input = keras.layers.Input(shape=(train_x.shape[1],train_x.shape[2]))
    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(input)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)

    #block 2

    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)
    x = keras.layers.Dropout(0.2)(x)

    #block 3
    for i in range(4):


        shortcut = MaxPooling1D(pool_size=1)(x)

        filters = 64 * ((i//2)+1)
        # print("Filter size = "+str(filters))
        x = keras.layers.Conv1D(kernel_size=16, filters=filters, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.LeakyReLU(alpha=0.3)(x)

        x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, padding="same", kernel_initializer='VarianceScaling')(x)

        x = keras.layers.LeakyReLU(alpha=0.3)(x)
        x = keras.layers.Dropout(0.2)(x)
    

        x = tf.keras.layers.Add()([x, shortcut])


    x = keras.layers.Conv1D(kernel_size=16, filters=32, strides=1, use_bias=True, kernel_initializer='VarianceScaling')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LeakyReLU(alpha=0.3)(x)
    x = keras.layers.Flatten()(x)
    out = keras.layers.Dense(9, activation='softmax')(x)
    model = tf.keras.models.Model(inputs=[input], outputs=out)
    model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
    return model

# %% [markdown]
# ### List of models

# %%
cnn1 = getCNNModel()
cnn2 = getCNNModel()
cnn3 = getCNNModel()
cnn4 = getCNNModel()
cnn5 = getCNNModel()
cnn6 = getCNNModel()
cnn7 = getCNNModel()
cnn8 = getCNNModel()
cnn9 = getCNNModel()
cnn10 = getCNNModel()

modellist = [cnn1, cnn2, cnn3, cnn4, cnn5, cnn6, cnn7, cnn8, cnn9, cnn10]

# %% [markdown]
# ### Fitting all the models

# %%
modelhistory = []
for m in range(len(modellist)):
  print("*"*10,"Model",m+1,"*"*10)
  modelhistory.append(modellist[m].fit(train_x,train_y,epochs=epochs,batch_size=batch_size,validation_split=0.1,verbose=verbose, callbacks=[reduce_lr]))
# Out:
# ********** Model 1 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 26s 1ms/sample - loss: 0.2141 - accuracy: 0.9339 - val_loss: 0.1287 - val_accuracy: 0.9565
# Epoch 2/10
# 26085/26085 [==============================] - 21s 816us/sample - loss: 0.0827 - accuracy: 0.9739 - val_loss: 0.0723 - val_accuracy: 0.9769
# Epoch 3/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0516 - accuracy: 0.9835 - val_loss: 0.0515 - val_accuracy: 0.9845
# Epoch 4/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0404 - accuracy: 0.9868 - val_loss: 0.0556 - val_accuracy: 0.9865
# Epoch 5/10
# 26085/26085 [==============================] - 22s 832us/sample - loss: 0.0324 - accuracy: 0.9895 - val_loss: 0.0475 - val_accuracy: 0.9897
# Epoch 6/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0286 - accuracy: 0.9912 - val_loss: 0.0570 - val_accuracy: 0.9890
# Epoch 7/10
# 26085/26085 [==============================] - 22s 838us/sample - loss: 0.0256 - accuracy: 0.9923 - val_loss: 0.0637 - val_accuracy: 0.9824
# Epoch 8/10
# 26085/26085 [==============================] - 22s 835us/sample - loss: 0.0126 - accuracy: 0.9969 - val_loss: 0.0436 - val_accuracy: 0.9900
# Epoch 9/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0085 - accuracy: 0.9985 - val_loss: 0.0419 - val_accuracy: 0.9900
# Epoch 10/10
# 26085/26085 [==============================] - 22s 833us/sample - loss: 0.0081 - accuracy: 0.9983 - val_loss: 0.0426 - val_accuracy: 0.9897
# ********** Model 2 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 24s 923us/sample - loss: 0.2934 - accuracy: 0.9117 - val_loss: 0.1493 - val_accuracy: 0.9603
# Epoch 2/10
# 26085/26085 [==============================] - 22s 836us/sample - loss: 0.1490 - accuracy: 0.9537 - val_loss: 0.1240 - val_accuracy: 0.9655
# Epoch 3/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.1223 - accuracy: 0.9619 - val_loss: 0.1069 - val_accuracy: 0.9717
# Epoch 4/10
# 26085/26085 [==============================] - 22s 835us/sample - loss: 0.1047 - accuracy: 0.9669 - val_loss: 0.0965 - val_accuracy: 0.9734
# Epoch 5/10
# 26085/26085 [==============================] - 22s 836us/sample - loss: 0.0932 - accuracy: 0.9713 - val_loss: 0.0898 - val_accuracy: 0.9738
# Epoch 6/10
# 26085/26085 [==============================] - 22s 836us/sample - loss: 0.0832 - accuracy: 0.9741 - val_loss: 0.0857 - val_accuracy: 0.9748
# Epoch 7/10
# 26085/26085 [==============================] - 22s 838us/sample - loss: 0.0747 - accuracy: 0.9775 - val_loss: 0.0812 - val_accuracy: 0.9793
# Epoch 8/10
# 26085/26085 [==============================] - 22s 842us/sample - loss: 0.0670 - accuracy: 0.9800 - val_loss: 0.0747 - val_accuracy: 0.9810
# Epoch 9/10
# 26085/26085 [==============================] - 22s 846us/sample - loss: 0.0616 - accuracy: 0.9809 - val_loss: 0.0717 - val_accuracy: 0.9810
# Epoch 10/10
# 26085/26085 [==============================] - 22s 845us/sample - loss: 0.0566 - accuracy: 0.9835 - val_loss: 0.0715 - val_accuracy: 0.9786
# ********** Model 3 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 24s 929us/sample - loss: 0.2830 - accuracy: 0.9130 - val_loss: 0.1462 - val_accuracy: 0.9569
# Epoch 2/10
# 26085/26085 [==============================] - 22s 843us/sample - loss: 0.1437 - accuracy: 0.9554 - val_loss: 0.1118 - val_accuracy: 0.9662
# Epoch 3/10
# 26085/26085 [==============================] - 22s 843us/sample - loss: 0.1157 - accuracy: 0.9638 - val_loss: 0.1000 - val_accuracy: 0.9703
# Epoch 4/10
# 26085/26085 [==============================] - 22s 845us/sample - loss: 0.1019 - accuracy: 0.9681 - val_loss: 0.0890 - val_accuracy: 0.9738
# Epoch 5/10
# 26085/26085 [==============================] - 22s 844us/sample - loss: 0.0891 - accuracy: 0.9735 - val_loss: 0.0831 - val_accuracy: 0.9769
# Epoch 6/10
# 26085/26085 [==============================] - 22s 838us/sample - loss: 0.0798 - accuracy: 0.9765 - val_loss: 0.0814 - val_accuracy: 0.9748
# Epoch 7/10
# 26085/26085 [==============================] - 22s 840us/sample - loss: 0.0715 - accuracy: 0.9791 - val_loss: 0.0734 - val_accuracy: 0.9803
# Epoch 8/10
# 26085/26085 [==============================] - 22s 837us/sample - loss: 0.0640 - accuracy: 0.9823 - val_loss: 0.0710 - val_accuracy: 0.9790
# Epoch 9/10
# 26085/26085 [==============================] - 22s 838us/sample - loss: 0.0586 - accuracy: 0.9825 - val_loss: 0.0641 - val_accuracy: 0.9817
# Epoch 10/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0533 - accuracy: 0.9850 - val_loss: 0.0633 - val_accuracy: 0.9796
# ********** Model 4 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 24s 907us/sample - loss: 0.2881 - accuracy: 0.9141 - val_loss: 0.1530 - val_accuracy: 0.9562
# Epoch 2/10
# 26085/26085 [==============================] - 22s 828us/sample - loss: 0.1479 - accuracy: 0.9548 - val_loss: 0.1199 - val_accuracy: 0.9641
# Epoch 3/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.1212 - accuracy: 0.9630 - val_loss: 0.1058 - val_accuracy: 0.9700
# Epoch 4/10
# 26085/26085 [==============================] - 22s 828us/sample - loss: 0.1025 - accuracy: 0.9684 - val_loss: 0.0964 - val_accuracy: 0.9696
# Epoch 5/10
# 26085/26085 [==============================] - 22s 833us/sample - loss: 0.0914 - accuracy: 0.9719 - val_loss: 0.0863 - val_accuracy: 0.9745
# Epoch 6/10
# 26085/26085 [==============================] - 22s 835us/sample - loss: 0.0805 - accuracy: 0.9757 - val_loss: 0.0821 - val_accuracy: 0.9765
# Epoch 7/10
# 26085/26085 [==============================] - 22s 833us/sample - loss: 0.0726 - accuracy: 0.9788 - val_loss: 0.0791 - val_accuracy: 0.9776
# Epoch 8/10
# 26085/26085 [==============================] - 22s 837us/sample - loss: 0.0656 - accuracy: 0.9803 - val_loss: 0.0716 - val_accuracy: 0.9810
# Epoch 9/10
# 26085/26085 [==============================] - 22s 838us/sample - loss: 0.0597 - accuracy: 0.9825 - val_loss: 0.0654 - val_accuracy: 0.9821
# Epoch 10/10
# 26085/26085 [==============================] - 22s 832us/sample - loss: 0.0549 - accuracy: 0.9841 - val_loss: 0.0652 - val_accuracy: 0.9807
# ********** Model 5 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 24s 905us/sample - loss: 0.2772 - accuracy: 0.9168 - val_loss: 0.1423 - val_accuracy: 0.9590
# Epoch 2/10
# 26085/26085 [==============================] - 22s 836us/sample - loss: 0.1356 - accuracy: 0.9579 - val_loss: 0.1138 - val_accuracy: 0.9676
# Epoch 3/10
# 26085/26085 [==============================] - 22s 834us/sample - loss: 0.1123 - accuracy: 0.9645 - val_loss: 0.1024 - val_accuracy: 0.9703
# Epoch 4/10
# 26085/26085 [==============================] - 22s 837us/sample - loss: 0.0964 - accuracy: 0.9698 - val_loss: 0.0942 - val_accuracy: 0.9727
# Epoch 5/10
# 26085/26085 [==============================] - 22s 835us/sample - loss: 0.0849 - accuracy: 0.9739 - val_loss: 0.0845 - val_accuracy: 0.9759
# Epoch 6/10
# 26085/26085 [==============================] - 22s 834us/sample - loss: 0.0763 - accuracy: 0.9776 - val_loss: 0.0795 - val_accuracy: 0.9776
# Epoch 7/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0686 - accuracy: 0.9803 - val_loss: 0.0745 - val_accuracy: 0.9796
# Epoch 8/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0622 - accuracy: 0.9811 - val_loss: 0.0712 - val_accuracy: 0.9814
# Epoch 9/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0578 - accuracy: 0.9827 - val_loss: 0.0675 - val_accuracy: 0.9824
# Epoch 10/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0523 - accuracy: 0.9852 - val_loss: 0.0649 - val_accuracy: 0.9793
# ********** Model 6 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 24s 917us/sample - loss: 0.2792 - accuracy: 0.9136 - val_loss: 0.1440 - val_accuracy: 0.9600
# Epoch 2/10
# 26085/26085 [==============================] - 22s 828us/sample - loss: 0.1428 - accuracy: 0.9552 - val_loss: 0.1173 - val_accuracy: 0.9686
# Epoch 3/10
# 26085/26085 [==============================] - 21s 824us/sample - loss: 0.1173 - accuracy: 0.9649 - val_loss: 0.1016 - val_accuracy: 0.9700
# Epoch 4/10
# 26085/26085 [==============================] - 22s 825us/sample - loss: 0.0996 - accuracy: 0.9708 - val_loss: 0.0926 - val_accuracy: 0.9745
# Epoch 5/10
# 26085/26085 [==============================] - 21s 802us/sample - loss: 0.0891 - accuracy: 0.9723 - val_loss: 0.0885 - val_accuracy: 0.9762
# Epoch 6/10
# 26085/26085 [==============================] - 21s 803us/sample - loss: 0.0792 - accuracy: 0.9761 - val_loss: 0.0795 - val_accuracy: 0.9776
# Epoch 7/10
# 26085/26085 [==============================] - 21s 802us/sample - loss: 0.0727 - accuracy: 0.9784 - val_loss: 0.0756 - val_accuracy: 0.9786
# Epoch 8/10
# 26085/26085 [==============================] - 21s 803us/sample - loss: 0.0650 - accuracy: 0.9810 - val_loss: 0.0755 - val_accuracy: 0.9800
# Epoch 9/10
# 26085/26085 [==============================] - 21s 802us/sample - loss: 0.0595 - accuracy: 0.9828 - val_loss: 0.0688 - val_accuracy: 0.9810
# Epoch 10/10
# 26085/26085 [==============================] - 21s 820us/sample - loss: 0.0552 - accuracy: 0.9839 - val_loss: 0.0648 - val_accuracy: 0.9807
# ********** Model 7 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 23s 899us/sample - loss: 0.2860 - accuracy: 0.9130 - val_loss: 0.1454 - val_accuracy: 0.9572
# Epoch 2/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.1455 - accuracy: 0.9554 - val_loss: 0.1205 - val_accuracy: 0.9655
# Epoch 3/10
# 26085/26085 [==============================] - 22s 833us/sample - loss: 0.1173 - accuracy: 0.9650 - val_loss: 0.1013 - val_accuracy: 0.9700
# Epoch 4/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.1008 - accuracy: 0.9698 - val_loss: 0.0924 - val_accuracy: 0.9721
# Epoch 5/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0900 - accuracy: 0.9724 - val_loss: 0.0869 - val_accuracy: 0.9765
# Epoch 6/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0809 - accuracy: 0.9752 - val_loss: 0.0798 - val_accuracy: 0.9765
# Epoch 7/10
# 26085/26085 [==============================] - 22s 833us/sample - loss: 0.0720 - accuracy: 0.9781 - val_loss: 0.0760 - val_accuracy: 0.9783
# Epoch 8/10
# 26085/26085 [==============================] - 22s 833us/sample - loss: 0.0647 - accuracy: 0.9808 - val_loss: 0.0716 - val_accuracy: 0.9793
# Epoch 9/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0606 - accuracy: 0.9824 - val_loss: 0.0673 - val_accuracy: 0.9817
# Epoch 10/10
# 26085/26085 [==============================] - 22s 832us/sample - loss: 0.0556 - accuracy: 0.9836 - val_loss: 0.0643 - val_accuracy: 0.9803
# ********** Model 8 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 24s 926us/sample - loss: 0.2967 - accuracy: 0.9107 - val_loss: 0.1533 - val_accuracy: 0.9583
# Epoch 2/10
# 26085/26085 [==============================] - 22s 834us/sample - loss: 0.1488 - accuracy: 0.9550 - val_loss: 0.1163 - val_accuracy: 0.9683
# Epoch 3/10
# 26085/26085 [==============================] - 22s 834us/sample - loss: 0.1188 - accuracy: 0.9644 - val_loss: 0.1016 - val_accuracy: 0.9721
# Epoch 4/10
# 26085/26085 [==============================] - 22s 835us/sample - loss: 0.1005 - accuracy: 0.9694 - val_loss: 0.0895 - val_accuracy: 0.9724
# Epoch 5/10
# 26085/26085 [==============================] - 22s 835us/sample - loss: 0.0884 - accuracy: 0.9735 - val_loss: 0.0836 - val_accuracy: 0.9769
# Epoch 6/10
# 26085/26085 [==============================] - 22s 835us/sample - loss: 0.0782 - accuracy: 0.9769 - val_loss: 0.0754 - val_accuracy: 0.9793
# Epoch 7/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0699 - accuracy: 0.9796 - val_loss: 0.0720 - val_accuracy: 0.9803
# Epoch 8/10
# 26085/26085 [==============================] - 22s 828us/sample - loss: 0.0631 - accuracy: 0.9814 - val_loss: 0.0675 - val_accuracy: 0.9803
# Epoch 9/10
# 26085/26085 [==============================] - 22s 828us/sample - loss: 0.0572 - accuracy: 0.9841 - val_loss: 0.0628 - val_accuracy: 0.9810
# Epoch 10/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0524 - accuracy: 0.9858 - val_loss: 0.0609 - val_accuracy: 0.9817
# ********** Model 9 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 23s 899us/sample - loss: 0.2882 - accuracy: 0.9120 - val_loss: 0.1484 - val_accuracy: 0.9552
# Epoch 2/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.1485 - accuracy: 0.9543 - val_loss: 0.1203 - val_accuracy: 0.9662
# Epoch 3/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.1207 - accuracy: 0.9625 - val_loss: 0.1059 - val_accuracy: 0.9700
# Epoch 4/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.1040 - accuracy: 0.9680 - val_loss: 0.0941 - val_accuracy: 0.9741
# Epoch 5/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0900 - accuracy: 0.9727 - val_loss: 0.0879 - val_accuracy: 0.9759
# Epoch 6/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0802 - accuracy: 0.9750 - val_loss: 0.0813 - val_accuracy: 0.9800
# Epoch 7/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0732 - accuracy: 0.9777 - val_loss: 0.0768 - val_accuracy: 0.9800
# Epoch 8/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0671 - accuracy: 0.9805 - val_loss: 0.0731 - val_accuracy: 0.9803
# Epoch 9/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.0608 - accuracy: 0.9819 - val_loss: 0.0655 - val_accuracy: 0.9828
# Epoch 10/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0549 - accuracy: 0.9842 - val_loss: 0.0641 - val_accuracy: 0.9831
# ********** Model 10 **********
# Train on 26085 samples, validate on 2899 samples
# Epoch 1/10
# 26085/26085 [==============================] - 24s 902us/sample - loss: 0.3052 - accuracy: 0.9065 - val_loss: 0.1581 - val_accuracy: 0.9545
# Epoch 2/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.1548 - accuracy: 0.9531 - val_loss: 0.1206 - val_accuracy: 0.9641
# Epoch 3/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.1239 - accuracy: 0.9619 - val_loss: 0.1058 - val_accuracy: 0.9669
# Epoch 4/10
# 26085/26085 [==============================] - 22s 831us/sample - loss: 0.1028 - accuracy: 0.9683 - val_loss: 0.0921 - val_accuracy: 0.9731
# Epoch 5/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0914 - accuracy: 0.9722 - val_loss: 0.0866 - val_accuracy: 0.9759
# Epoch 6/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0810 - accuracy: 0.9765 - val_loss: 0.0795 - val_accuracy: 0.9800
# Epoch 7/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0709 - accuracy: 0.9789 - val_loss: 0.0713 - val_accuracy: 0.9810
# Epoch 8/10
# 26085/26085 [==============================] - 22s 830us/sample - loss: 0.0644 - accuracy: 0.9818 - val_loss: 0.0685 - val_accuracy: 0.9807
# Epoch 9/10
# 26085/26085 [==============================] - 22s 828us/sample - loss: 0.0584 - accuracy: 0.9828 - val_loss: 0.0631 - val_accuracy: 0.9828
# Epoch 10/10
# 26085/26085 [==============================] - 22s 829us/sample - loss: 0.0535 - accuracy: 0.9845 - val_loss: 0.0634 - val_accuracy: 0.9828

# %% [markdown]
# ### Model predictions

# %%
modelpreds = []
for m in range(len(modellist)):
  print("*"*10, "Model", m+1, "*"*10)
  modelpreds.append(np.argmax(modellist[m].predict(test_x, verbose=1),axis=1))
# Out:
# ********** Model 1 **********
# 27219/27219 [==============================] - 7s 249us/sample
# ********** Model 2 **********
# 27219/27219 [==============================] - 7s 242us/sample
# ********** Model 3 **********
# 27219/27219 [==============================] - 7s 245us/sample
# ********** Model 4 **********
# 27219/27219 [==============================] - 7s 244us/sample
# ********** Model 5 **********
# 27219/27219 [==============================] - 7s 242us/sample
# ********** Model 6 **********
# 27219/27219 [==============================] - 6s 239us/sample
# ********** Model 7 **********
# 27219/27219 [==============================] - 6s 237us/sample
# ********** Model 8 **********
# 27219/27219 [==============================] - 7s 255us/sample
# ********** Model 9 **********
# 27219/27219 [==============================] - 6s 236us/sample
# ********** Model 10 **********
# 27219/27219 [==============================] - 6s 236us/sample

# %% [markdown]
# ### Generating the metrics

# %%
results = []
cnn_actual_value=np.argmax(test_y,axis=1)
for p in range(len(modelpreds)):
  print("*"*10,"Model",p+1,"*"*10)
  results.append(showResults(cnn_actual_value, modelpreds[p],'CNN'+str(p)))
# Out:
# ********** Model 1 **********
# Accuracy  : 0.9729233256181344
# Precision : 0.8756177792908136
# Recall : 0.9723981742068124
# f1score macro : 0.9150189083492142
# f1score micro : 0.9729233256181344
# ********** Model 2 **********
# Accuracy  : 0.941658400382086
# Precision : 0.8027151651238343
# Recall : 0.9649634155136311
# f1score macro : 0.8497629876017896
# f1score micro : 0.941658400382086
# ********** Model 3 **********
# Accuracy  : 0.9603953120981668
# Precision : 0.8299117307397563
# Recall : 0.9697093010383817
# f1score macro : 0.8778843544695054
# f1score micro : 0.9603953120981668
# ********** Model 4 **********
# Accuracy  : 0.9622690032697748
# Precision : 0.8355381344276913
# Recall : 0.9618930210214074
# f1score macro : 0.8813138959788185
# f1score micro : 0.9622690032697748
# ********** Model 5 **********
# Accuracy  : 0.9596605312465557
# Precision : 0.8353713007600225
# Recall : 0.9657254336730319
# f1score macro : 0.885845851474949
# f1score micro : 0.9596605312465557
# ********** Model 6 **********
# Accuracy  : 0.9630772622065469
# Precision : 0.8397499692205714
# Recall : 0.9701603793572094
# f1score macro : 0.8882968716648448
# f1score micro : 0.9630772622065469
# ********** Model 7 **********
# Accuracy  : 0.9518351151768984
# Precision : 0.8166698906386034
# Recall : 0.9660528523097729
# f1score macro : 0.8696692138311246
# f1score micro : 0.9518351151768984
# ********** Model 8 **********
# Accuracy  : 0.9573092325214005
# Precision : 0.8222700785432551
# Recall : 0.9672279359266306
# f1score macro : 0.8717790600630597
# f1score micro : 0.9573092325214005
# ********** Model 9 **********
# Accuracy  : 0.9593666189059114
# Precision : 0.8331141194663426
# Recall : 0.965766004630309
# f1score macro : 0.8801450754172264
# f1score micro : 0.9593666189059114
# ********** Model 10 **********
# Accuracy  : 0.9578235791175282
# Precision : 0.8276000578367817
# Recall : 0.9643626484530883
# f1score macro : 0.8752810080478055
# f1score micro : 0.9578235791175282

# %% [markdown]
# ### Generating the confusion matrices

# %%
cms = []
for p in modelpreds:
  cms.append(confusion_matrix(cnn_actual_value, p, normalize='true'))

# %% [markdown]
# ### Extracting model train and validation accuracy & losses.

# %%
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for h in modelhistory:
  modelosses.append(h.history['loss'])
  modeleval_losses.append(h.history['val_loss'])
  modelacc.append(h.history['accuracy'])
  modeleval_acc.append(h.history['val_accuracy'])
modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)
# losses , eval_losses, accuracy, eval_accuracy
history = np.array([modelosses, modeleval_losses, modelacc, modeleval_acc])

# %% [markdown]
# ### Saving the data

# %%
# Saving data LSTM patient leavout
new_path = path+"eval_data_10k/cnn_ph/"

modelpreds = np.array(modelpreds)
results = np.array(results)
cms = np.array(cms)
# modelhistory = np.array(modelhistory)
np.save(new_path+"cnn_modelpreds.npy", modelpreds)
np.save(new_path+"cnn_results.npy", results)
np.save(new_path+"cnn_cms.npy", cms)
np.save(new_path+"cnn_history.npy", history)
# Out:
# C:\Users\podda\anaconda3\envs\ecg\lib\site-packages\ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """

# %% [markdown]
# Visualising the Mean Confusion Matrix

# %%
categories=['N','L','R','V','A','F','f','/']
cm = np.mean(cms, axis=0)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, xticklabels=categories, yticklabels=categories)
plt.title('CNN - 10k Mean Confusion Matrix')
# plt.savefig("lstm_mean_cm_pl.png", dpi=300)
plt.show()

# %% [markdown]
# ### Mean Metrics

# %%
metrics = ["Accuracy", "Precision", "Recall", "f1-score macro", "f1-score micro"]
mean_metrics = np.mean(results[:,1:6], axis=0)
for i in range(len(mean_metrics)):
  print(metrics[i],":",mean_metrics[i])
# Out:
# Accuracy : 0.9586
# Precision : 0.8320000000000001
# Recall : 0.9667999999999999
# f1-score macro : 0.8795
# f1-score micro : 0.9586

# %% [markdown]
# ### Mesn CNN Loss vs Accuracy Plot

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 5))
ax[0].plot(np.mean(modelosses, axis=0))
ax[0].plot(np.mean(modeleval_losses, axis=0))
ax[0].set_title('LSTM loss')
ax[0].set_ylabel('loss')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'val'], loc='upper right')
ax[1].plot(np.mean(modelacc,axis=0))
ax[1].plot(np.mean(modeleval_acc, axis=0))
ax[1].set_title('LSTM accuracy')
ax[1].set_ylabel('accuracy')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'val'], loc='upper left')
plt.show()
# fig.savefig('lstm_leaveout_patients_loss_and_accuracy.jpg')
