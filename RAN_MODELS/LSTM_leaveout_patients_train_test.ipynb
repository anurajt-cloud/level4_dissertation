# %% [markdown]
# -------------------------------------
# # ECG Beat classification:
# ### Model - LSTM
#
# ### Data Method - Patient leave-out
#
# -------------------------------------

# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
from scipy import *
import os
import seaborn as sns
from sklearn import *
from sklearn.metrics import *
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import MaxPooling1D

# %%
# from google.colab import drive
# drive.mount('/content/drive')

print("You are using Tensorflow version", tf.__version__)

print(tf.config.list_physical_devices('GPU'))
# Out:
# Mounted at /content/drive

# %%
# path = './drive/MyDrive/Colab_Notebooks/ECG_with_Expected_gradients/'
path = './'

# %% [markdown]
# ### Loading data

# %%
# Loading Data
train_c1 = np.genfromtxt(path+'Data/train_patients_sc.csv', delimiter=',')
train_c0 = np.genfromtxt(path+'Data/train_patients_fc.csv', delimiter=',')
test_c1 = np.genfromtxt(path+'Data/test_patients_sc.csv', delimiter=',')
test_c0 = np.genfromtxt(path+'Data/test_patients_fc.csv', delimiter=',')

train_x_c01 = np.concatenate((train_c0[:, :-2], train_c1[:, :-2]), axis=1)
train_y_c01 = np.concatenate((train_c0[:, -2:], train_c1[:, -2:]), axis=1)

test_x_c01 = np.concatenate((test_c0[:, :-2], test_c1[:, :-2]), axis=1)
test_y_c01 = np.concatenate((test_c0[:, -2:], test_c0[:, -2:]), axis=1)

train_x = train_x_c01.reshape(-1, train_x_c01.shape[1], 1).astype('float32')
test_x = test_x_c01.reshape(-1, test_x_c01.shape[1], 1).astype('float32')

train_y = tf.keras.utils.to_categorical(train_y_c01[:,0])
test_y = tf.keras.utils.to_categorical(test_y_c01[:,0])

print("Train:")
print("x:", train_x.shape, "y:", train_y.shape)
print("Test")
print("x:", test_x.shape, "y:", test_y.shape)
# Out:
# Train:
# x: (32048, 920, 1) y: (32048, 9)
# Test
# x: (9902, 920, 1) y: (9902, 9)

# %% [markdown]
# ### Create a performance metrics function

# %%
def showResults(test, pred, model_name):
    accuracy = accuracy_score(test, pred)
    precision= precision_score(test, pred, average='macro')
    recall = recall_score(test, pred, average = 'macro')
    f1score_macro = f1_score(test, pred, average='macro') 
    f1score_micro = f1_score(test, pred, average='micro') 
    print("Accuracy  : {}".format(accuracy))
    print("Precision : {}".format(precision))
    print("Recall : {}".format(recall))
    print("f1score macro : {}".format(f1score_macro))
    print("f1score micro : {}".format(f1score_micro))
    cm=confusion_matrix(test, pred, labels=[1,2,3,4,5,6,7,8])
    return (model_name, round(accuracy,3), round(precision,3) , round(recall,3) , round(f1score_macro,3), 
            round(f1score_micro, 3), cm)

# %% [markdown]
# ### Function for building the LSTM model

# %%
verbose, epoch, batch_size = 1, 10, 256
activationFunction='relu'

def getlstmModel():
    
    lstmmodel = Sequential()
    lstmmodel.add(LSTM(128, return_sequences=True, input_shape=(train_x.shape[1],train_x.shape[2])))
    lstmmodel.add(LSTM(9, return_sequences=True))
    lstmmodel.add(MaxPooling1D(pool_size=4,padding='same'))
    lstmmodel.add(Flatten())
    lstmmodel.add(Dense(256, activation=tf.nn.relu))    
    lstmmodel.add(Dense(128, activation=tf.nn.relu))    
    lstmmodel.add(Dense(32, activation=tf.nn.relu))
    lstmmodel.add(Dense(9, activation='softmax'))
    lstmmodel.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    # lstmmodel.summary()
    return lstmmodel
# lstmmodel = getlstmModel()

# lstmhistory= lstmmodel.fit(train_x, train_y, epochs=epoch, verbose=verbose, validation_split=0.2, batch_size = batch_size)
# lstmpredictions = lstmmodel.predict(test_x, verbose=1)

# %% [markdown]
# ### List of models

# %%
lstm1 = getlstmModel()
lstm2 = getlstmModel()
lstm3 = getlstmModel()
lstm4 = getlstmModel()
lstm5 = getlstmModel()
lstm6 = getlstmModel()
lstm7 = getlstmModel()
lstm8 = getlstmModel()
lstm9 = getlstmModel()
lstm10 = getlstmModel()

modellist = [lstm1,lstm2,lstm3,lstm4,lstm5,lstm6,lstm7,lstm8,lstm9,lstm10]

# %% [markdown]
# ### Fitting all the models

# %%
modelhistory = []
for m in modellist:
  modelhistory.append(m.fit(train_x, train_y, epochs=epoch, verbose=verbose, validation_split=0.2, batch_size = batch_size))
# Out:
# Epoch 1/10
# 101/101 [==============================] - 47s 376ms/step - loss: 0.3347 - accuracy: 0.9002 - val_loss: 0.1171 - val_accuracy: 0.9615
# Epoch 2/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0751 - accuracy: 0.9778 - val_loss: 0.0893 - val_accuracy: 0.9685
# Epoch 3/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0521 - accuracy: 0.9844 - val_loss: 0.0502 - val_accuracy: 0.9835
# Epoch 4/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0272 - accuracy: 0.9920 - val_loss: 0.0418 - val_accuracy: 0.9881
# Epoch 5/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0221 - accuracy: 0.9933 - val_loss: 0.0387 - val_accuracy: 0.9902
# Epoch 6/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0161 - accuracy: 0.9956 - val_loss: 0.0466 - val_accuracy: 0.9860
# Epoch 7/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 0.0434 - val_accuracy: 0.9885
# Epoch 8/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0121 - accuracy: 0.9968 - val_loss: 0.0407 - val_accuracy: 0.9895
# Epoch 9/10
# 101/101 [==============================] - 37s 364ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.0443 - val_accuracy: 0.9871
# Epoch 10/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0140 - accuracy: 0.9963 - val_loss: 0.0468 - val_accuracy: 0.9891
# Epoch 1/10
# 101/101 [==============================] - 39s 348ms/step - loss: 0.3463 - accuracy: 0.8962 - val_loss: 0.1019 - val_accuracy: 0.9669
# Epoch 2/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0711 - accuracy: 0.9781 - val_loss: 0.0640 - val_accuracy: 0.9805
# Epoch 3/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0430 - accuracy: 0.9879 - val_loss: 0.0486 - val_accuracy: 0.9863
# Epoch 4/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0268 - accuracy: 0.9924 - val_loss: 0.0562 - val_accuracy: 0.9846
# Epoch 5/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0304 - accuracy: 0.9908 - val_loss: 0.0462 - val_accuracy: 0.9871
# Epoch 6/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.0499 - val_accuracy: 0.9860
# Epoch 7/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0116 - accuracy: 0.9967 - val_loss: 0.0452 - val_accuracy: 0.9869
# Epoch 8/10
# 101/101 [==============================] - 34s 334ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.0354 - val_accuracy: 0.9880
# Epoch 9/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.0380 - val_accuracy: 0.9892
# Epoch 10/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.0378 - val_accuracy: 0.9892
# Epoch 1/10
# 101/101 [==============================] - 40s 352ms/step - loss: 0.3379 - accuracy: 0.8955 - val_loss: 0.0956 - val_accuracy: 0.9693
# Epoch 2/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0742 - accuracy: 0.9779 - val_loss: 0.0631 - val_accuracy: 0.9808
# Epoch 3/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0431 - accuracy: 0.9875 - val_loss: 0.0520 - val_accuracy: 0.9833
# Epoch 4/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0272 - accuracy: 0.9924 - val_loss: 0.0611 - val_accuracy: 0.9853
# Epoch 5/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0200 - accuracy: 0.9943 - val_loss: 0.0385 - val_accuracy: 0.9894
# Epoch 6/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0156 - accuracy: 0.9960 - val_loss: 0.0406 - val_accuracy: 0.9892
# Epoch 7/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0142 - accuracy: 0.9961 - val_loss: 0.0406 - val_accuracy: 0.9874
# Epoch 8/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.0349 - val_accuracy: 0.9899
# Epoch 9/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.0393 - val_accuracy: 0.9885
# Epoch 10/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.0405 - val_accuracy: 0.9905
# Epoch 1/10
# 101/101 [==============================] - 39s 349ms/step - loss: 0.3399 - accuracy: 0.8994 - val_loss: 0.0976 - val_accuracy: 0.9679
# Epoch 2/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0788 - accuracy: 0.9757 - val_loss: 0.0722 - val_accuracy: 0.9758
# Epoch 3/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0445 - accuracy: 0.9870 - val_loss: 0.0493 - val_accuracy: 0.9846
# Epoch 4/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0362 - accuracy: 0.9887 - val_loss: 0.0462 - val_accuracy: 0.9861
# Epoch 5/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0210 - accuracy: 0.9938 - val_loss: 0.0659 - val_accuracy: 0.9783
# Epoch 6/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0232 - accuracy: 0.9931 - val_loss: 0.0488 - val_accuracy: 0.9855
# Epoch 7/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0162 - accuracy: 0.9954 - val_loss: 0.0438 - val_accuracy: 0.9878
# Epoch 8/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0154 - accuracy: 0.9955 - val_loss: 0.0452 - val_accuracy: 0.9886
# Epoch 9/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0110 - accuracy: 0.9970 - val_loss: 0.0453 - val_accuracy: 0.9899
# Epoch 10/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.0450 - val_accuracy: 0.9885
# Epoch 1/10
# 101/101 [==============================] - 39s 350ms/step - loss: 0.3667 - accuracy: 0.8870 - val_loss: 0.1264 - val_accuracy: 0.9541
# Epoch 2/10
# 101/101 [==============================] - 34s 341ms/step - loss: 0.0769 - accuracy: 0.9776 - val_loss: 0.0848 - val_accuracy: 0.9738
# Epoch 3/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0466 - accuracy: 0.9863 - val_loss: 0.0531 - val_accuracy: 0.9833
# Epoch 4/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0286 - accuracy: 0.9912 - val_loss: 0.0474 - val_accuracy: 0.9864
# Epoch 5/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0215 - accuracy: 0.9931 - val_loss: 0.0395 - val_accuracy: 0.9872
# Epoch 6/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0215 - accuracy: 0.9931 - val_loss: 0.0502 - val_accuracy: 0.9849
# Epoch 7/10
# 101/101 [==============================] - 34s 341ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.0473 - val_accuracy: 0.9858
# Epoch 8/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0154 - accuracy: 0.9956 - val_loss: 0.0317 - val_accuracy: 0.9911
# Epoch 9/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0353 - val_accuracy: 0.9885
# Epoch 10/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0391 - val_accuracy: 0.9877
# Epoch 1/10
# 101/101 [==============================] - 39s 352ms/step - loss: 0.3313 - accuracy: 0.9013 - val_loss: 0.1023 - val_accuracy: 0.9680
# Epoch 2/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0738 - accuracy: 0.9778 - val_loss: 0.0669 - val_accuracy: 0.9808
# Epoch 3/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0422 - accuracy: 0.9880 - val_loss: 0.0613 - val_accuracy: 0.9814
# Epoch 4/10
# 101/101 [==============================] - 34s 341ms/step - loss: 0.0355 - accuracy: 0.9888 - val_loss: 0.0480 - val_accuracy: 0.9867
# Epoch 5/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0222 - accuracy: 0.9932 - val_loss: 0.0425 - val_accuracy: 0.9877
# Epoch 6/10
# 101/101 [==============================] - 34s 341ms/step - loss: 0.0185 - accuracy: 0.9945 - val_loss: 0.0487 - val_accuracy: 0.9861
# Epoch 7/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0135 - accuracy: 0.9964 - val_loss: 0.0534 - val_accuracy: 0.9863
# Epoch 8/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0166 - accuracy: 0.9951 - val_loss: 0.0573 - val_accuracy: 0.9833
# Epoch 9/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0114 - accuracy: 0.9969 - val_loss: 0.0372 - val_accuracy: 0.9911
# Epoch 10/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0455 - val_accuracy: 0.9891
# Epoch 1/10
# 101/101 [==============================] - 39s 349ms/step - loss: 0.3539 - accuracy: 0.8923 - val_loss: 0.1062 - val_accuracy: 0.9691
# Epoch 2/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0704 - accuracy: 0.9787 - val_loss: 0.0623 - val_accuracy: 0.9817
# Epoch 3/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0392 - accuracy: 0.9891 - val_loss: 0.0552 - val_accuracy: 0.9842
# Epoch 4/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0269 - accuracy: 0.9926 - val_loss: 0.0374 - val_accuracy: 0.9894
# Epoch 5/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0216 - accuracy: 0.9938 - val_loss: 0.0444 - val_accuracy: 0.9871
# Epoch 6/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0177 - accuracy: 0.9949 - val_loss: 0.0425 - val_accuracy: 0.9871
# Epoch 7/10
# 101/101 [==============================] - 34s 342ms/step - loss: 0.0151 - accuracy: 0.9957 - val_loss: 0.0456 - val_accuracy: 0.9864
# Epoch 8/10
# 101/101 [==============================] - 34s 340ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.0431 - val_accuracy: 0.9895
# Epoch 9/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.0493 - val_accuracy: 0.9875
# Epoch 10/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0134 - accuracy: 0.9963 - val_loss: 0.0391 - val_accuracy: 0.9905
# Epoch 1/10
# 101/101 [==============================] - 40s 350ms/step - loss: 0.3520 - accuracy: 0.8962 - val_loss: 0.0946 - val_accuracy: 0.9685
# Epoch 2/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0738 - accuracy: 0.9771 - val_loss: 0.0665 - val_accuracy: 0.9771
# Epoch 3/10
# 101/101 [==============================] - 34s 334ms/step - loss: 0.0413 - accuracy: 0.9878 - val_loss: 0.0489 - val_accuracy: 0.9846
# Epoch 4/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0282 - accuracy: 0.9921 - val_loss: 0.0555 - val_accuracy: 0.9878
# Epoch 5/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0201 - accuracy: 0.9943 - val_loss: 0.0520 - val_accuracy: 0.9869
# Epoch 6/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0182 - accuracy: 0.9952 - val_loss: 0.0576 - val_accuracy: 0.9803
# Epoch 7/10
# 101/101 [==============================] - 34s 339ms/step - loss: 0.0192 - accuracy: 0.9945 - val_loss: 0.0481 - val_accuracy: 0.9866
# Epoch 8/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0147 - accuracy: 0.9960 - val_loss: 0.0502 - val_accuracy: 0.9869
# Epoch 9/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.0474 - val_accuracy: 0.9860
# Epoch 10/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 0.0526 - val_accuracy: 0.9871
# Epoch 1/10
# 101/101 [==============================] - 39s 346ms/step - loss: 0.3660 - accuracy: 0.8852 - val_loss: 0.1041 - val_accuracy: 0.9663
# Epoch 2/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0708 - accuracy: 0.9791 - val_loss: 0.0634 - val_accuracy: 0.9828
# Epoch 3/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0406 - accuracy: 0.9882 - val_loss: 0.0440 - val_accuracy: 0.9877
# Epoch 4/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0273 - accuracy: 0.9918 - val_loss: 0.0412 - val_accuracy: 0.9872
# Epoch 5/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 0.0379 - val_accuracy: 0.9888
# Epoch 6/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.0534 - val_accuracy: 0.9860
# Epoch 7/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0121 - accuracy: 0.9965 - val_loss: 0.0549 - val_accuracy: 0.9856
# Epoch 8/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.0486 - val_accuracy: 0.9830
# Epoch 9/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0433 - val_accuracy: 0.9894
# Epoch 10/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0421 - val_accuracy: 0.9895
# Epoch 1/10
# 101/101 [==============================] - 41s 369ms/step - loss: 0.3334 - accuracy: 0.8975 - val_loss: 0.1324 - val_accuracy: 0.9551
# Epoch 2/10
# 101/101 [==============================] - 34s 334ms/step - loss: 0.0811 - accuracy: 0.9743 - val_loss: 0.0637 - val_accuracy: 0.9807
# Epoch 3/10
# 101/101 [==============================] - 34s 334ms/step - loss: 0.0454 - accuracy: 0.9862 - val_loss: 0.0570 - val_accuracy: 0.9835
# Epoch 4/10
# 101/101 [==============================] - 34s 333ms/step - loss: 0.0295 - accuracy: 0.9906 - val_loss: 0.0425 - val_accuracy: 0.9853
# Epoch 5/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0208 - accuracy: 0.9943 - val_loss: 0.0485 - val_accuracy: 0.9864
# Epoch 6/10
# 101/101 [==============================] - 34s 337ms/step - loss: 0.0199 - accuracy: 0.9939 - val_loss: 0.0415 - val_accuracy: 0.9878
# Epoch 7/10
# 101/101 [==============================] - 34s 336ms/step - loss: 0.0122 - accuracy: 0.9967 - val_loss: 0.0424 - val_accuracy: 0.9897
# Epoch 8/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0122 - accuracy: 0.9968 - val_loss: 0.0377 - val_accuracy: 0.9905
# Epoch 9/10
# 101/101 [==============================] - 34s 335ms/step - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.0476 - val_accuracy: 0.9877
# Epoch 10/10
# 101/101 [==============================] - 34s 338ms/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 0.0472 - val_accuracy: 0.9880

# %% [markdown]
# ### Model predictions

# %%
modelpreds = []
for m in range(len(modellist)):
  print("*"*10,"Model",m+1,"*"*10)
  modelpreds.append(np.argmax(modellist[m].predict(test_x, verbose=1),axis=1))
# Out:
# ********** Model 1 **********
# 310/310 [==============================] - 33s 103ms/step
# ********** Model 2 **********
# 310/310 [==============================] - 32s 101ms/step
# ********** Model 3 **********
# 310/310 [==============================] - 33s 105ms/step
# ********** Model 4 **********
# 310/310 [==============================] - 33s 104ms/step
# ********** Model 5 **********
# 310/310 [==============================] - 35s 106ms/step
# ********** Model 6 **********
# 310/310 [==============================] - 34s 105ms/step
# ********** Model 7 **********
# 310/310 [==============================] - 33s 102ms/step
# ********** Model 8 **********
# 310/310 [==============================] - 34s 107ms/step
# ********** Model 9 **********
# 310/310 [==============================] - 34s 107ms/step
# ********** Model 10 **********
# 310/310 [==============================] - 33s 105ms/step

# %% [markdown]
# ### Generating the metrics

# %%
results = []
lstm_actual_value=np.argmax(test_y,axis=1)
for p in range(len(modelpreds)):
  print("*"*10,"Model",p+1,"*"*10)
  results.append(showResults(lstm_actual_value, modelpreds[p],'LSTM'+str(p)))
# Out:
# ********** Model 1 **********
# Accuracy  : 0.6519894970712987
# Precision : 0.3868125337862537
# Recall : 0.37340844429070114
# f1score macro : 0.3350490269573188
# f1score micro : 0.6519894970712987
# ********** Model 2 **********
# Accuracy  : 0.6571399717228843
# Precision : 0.437502903607669
# Recall : 0.34082045740527556
# f1score macro : 0.31231090309973264
# f1score micro : 0.6571399717228843
# ********** Model 3 **********
# Accuracy  : 0.6915774590991719
# Precision : 0.4551127170867314
# Recall : 0.3687961436176946
# f1score macro : 0.35006218988206755
# f1score micro : 0.6915774590991719
# ********** Model 4 **********
# Accuracy  : 0.71884467784286
# Precision : 0.4123923287507807
# Recall : 0.3892735604228077
# f1score macro : 0.3709054996847949
# f1score micro : 0.71884467784286
# ********** Model 5 **********
# Accuracy  : 0.6806705716016966
# Precision : 0.37655590198137096
# Recall : 0.3618947845099323
# f1score macro : 0.3269933960739203
# f1score micro : 0.6806705716016966
# ********** Model 6 **********
# Accuracy  : 0.7671177539890931
# Precision : 0.4061778303657197
# Recall : 0.43730551034733733
# f1score macro : 0.40074363904398036
# f1score micro : 0.7671177539890931
# ********** Model 7 **********
# Accuracy  : 0.5880630175722076
# Precision : 0.4054523701641102
# Recall : 0.3396586958276551
# f1score macro : 0.3328619442520133
# f1score micro : 0.5880630175722076
# ********** Model 8 **********
# Accuracy  : 0.6474449606140174
# Precision : 0.3895334905571673
# Recall : 0.37703414682048064
# f1score macro : 0.36812644727516175
# f1score micro : 0.6474449606140174
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ********** Model 9 **********
# Accuracy  : 0.7395475661482529
# Precision : 0.39627000755910213
# Recall : 0.4084461660310573
# f1score macro : 0.371624670642113
# f1score micro : 0.7395475661482529
# ********** Model 10 **********
# Accuracy  : 0.667541910725106
# Precision : 0.38544395993499697
# Recall : 0.35050309731435236
# f1score macro : 0.29338626151584657
# f1score micro : 0.667541910725106
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Generating the confusion matrices

# %%
cms = []
for p in modelpreds:
  cms.append(confusion_matrix(lstm_actual_value, p, normalize='true'))

# %% [markdown]
# ### Extracting model train and validation accuracy & loss

# %%
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for h in modelhistory:
  modelosses.append(h.history['loss'])
  modeleval_losses.append(h.history['val_loss'])
  modelacc.append(h.history['accuracy'])
  modeleval_acc.append(h.history['val_accuracy'])
modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)
# losses , eval_losses, accuracy, eval_accuracy
history = np.array([modelosses, modeleval_losses, modelacc, modeleval_acc])

# %% [markdown]
# ### Saving the data

# %%
# Saving data LSTM patient leavout
new_path = path+"eval_data_10k/lstm_pl/"

modelpreds = np.array(modelpreds)
results = np.array(results)
cms = np.array(cms)
# modelhistory = np.array(modelhistory)
np.save(new_path+"lstm_modelpreds.npy", modelpreds)
np.save(new_path+"lstm_results.npy", results)
np.save(new_path+"lstm_cms.npy", cms)
np.save(new_path+"lstm_history.npy", history )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   """
# WARNING:absl:Found untraced functions such as lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses, lstm_cell_21_layer_call_fn, lstm_cell_21_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://6bbc9c8d-08bc-44eb-ac13-2e48b7583c62/assets
# INFO:tensorflow:Assets written to: ram://6bbc9c8d-08bc-44eb-ac13-2e48b7583c62/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c67a2090> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c678c850> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_22_layer_call_fn, lstm_cell_22_layer_call_and_return_conditional_losses, lstm_cell_23_layer_call_fn, lstm_cell_23_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://78cc84a1-027f-4c38-9ced-83358cf2ac13/assets
# INFO:tensorflow:Assets written to: ram://78cc84a1-027f-4c38-9ced-83358cf2ac13/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c8d9ef90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c8ddee50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_24_layer_call_fn, lstm_cell_24_layer_call_and_return_conditional_losses, lstm_cell_25_layer_call_fn, lstm_cell_25_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://f1497d8e-5fbf-4cde-b0f4-c2afc343e486/assets
# INFO:tensorflow:Assets written to: ram://f1497d8e-5fbf-4cde-b0f4-c2afc343e486/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff584461a90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff58cbaf310> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_26_layer_call_fn, lstm_cell_26_layer_call_and_return_conditional_losses, lstm_cell_27_layer_call_fn, lstm_cell_27_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://fa06eeef-2769-42e9-830e-d586f6edf41d/assets
# INFO:tensorflow:Assets written to: ram://fa06eeef-2769-42e9-830e-d586f6edf41d/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5b10b9050> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5b0b3f490> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_28_layer_call_fn, lstm_cell_28_layer_call_and_return_conditional_losses, lstm_cell_29_layer_call_fn, lstm_cell_29_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://ceb3c699-0446-4580-a8a8-4df3cd6d0d12/assets
# INFO:tensorflow:Assets written to: ram://ceb3c699-0446-4580-a8a8-4df3cd6d0d12/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5bdb07190> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff59e5dec90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_30_layer_call_fn, lstm_cell_30_layer_call_and_return_conditional_losses, lstm_cell_31_layer_call_fn, lstm_cell_31_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://2854a6bb-4e9b-4e20-bb49-1851bc8e65be/assets
# INFO:tensorflow:Assets written to: ram://2854a6bb-4e9b-4e20-bb49-1851bc8e65be/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c8c94cd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5bdafa450> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_32_layer_call_fn, lstm_cell_32_layer_call_and_return_conditional_losses, lstm_cell_33_layer_call_fn, lstm_cell_33_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://b1217893-0221-4749-91ab-1e751e8549e1/assets
# INFO:tensorflow:Assets written to: ram://b1217893-0221-4749-91ab-1e751e8549e1/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5b1e3d790> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff58fff95d0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_34_layer_call_fn, lstm_cell_34_layer_call_and_return_conditional_losses, lstm_cell_35_layer_call_fn, lstm_cell_35_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://43204350-25da-4f4c-8946-32d485301f4b/assets
# INFO:tensorflow:Assets written to: ram://43204350-25da-4f4c-8946-32d485301f4b/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5b18bab50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c8046a90> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_36_layer_call_fn, lstm_cell_36_layer_call_and_return_conditional_losses, lstm_cell_37_layer_call_fn, lstm_cell_37_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://fc2ee0c1-1488-4ec6-8425-7a67652a57cd/assets
# INFO:tensorflow:Assets written to: ram://fc2ee0c1-1488-4ec6-8425-7a67652a57cd/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c606bc10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5b6d2edd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:Found untraced functions such as lstm_cell_38_layer_call_fn, lstm_cell_38_layer_call_and_return_conditional_losses, lstm_cell_39_layer_call_fn, lstm_cell_39_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://22cb4ffe-1644-4e13-a83a-4ac70702e4ac/assets
# INFO:tensorflow:Assets written to: ram://22cb4ffe-1644-4e13-a83a-4ac70702e4ac/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5b15e2a10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7ff5c81c3190> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# ### Visualising the Mean Confusion Matrix

# %%
categories=['N','L','R','V','A','F','f','/']
cm = np.mean(cms, axis=0)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, xticklabels=categories, yticklabels=categories)
plt.title('LSTM - 10k Mean Confusion Matrix')
# plt.savefig("lstm_mean_cm_pl.png", dpi=300)
plt.show()

# %% [markdown]
# ### Mean Metrics

# %%
metrics = ["Accuracy", "Precision", "Recall", "f1-score macro", "f1-score micro"]
mean_metrics = np.mean(results[:,1:6], axis=0)
for i in range(len(mean_metrics)):
  print(metrics[i],":",mean_metrics[i])
# Out:
# Accuracy : 0.6811
# Precision : 0.4051
# Recall : 0.3746999999999999
# f1-score macro : 0.3462
# f1-score micro : 0.6811

# %% [markdown]
# ### Mean LSTM Loss vs Accuracy Plot

# %%
# Save the model so we can visualize it with Netron (https://github.com/lutzroeder/netron):
# tf.keras.models.save_model(lstmmodel, 'lstmmodel_module2.h5')
modelosses = []
modeleval_losses = []
modelacc = []
modeleval_acc = []
for h in modelhistory:
  modelosses.append(h.history['loss'])
  modeleval_losses.append(h.history['val_loss'])
  modelacc.append(h.history['accuracy'])
  modeleval_acc.append(h.history['val_accuracy'])
modelosses = np.array(modelosses)
modeleval_losses = np.array(modeleval_losses)
modelacc = np.array(modelacc)
modeleval_acc = np.array(modeleval_acc)

# %%
fig, ax = plt.subplots(1, 2, figsize = (16, 5))
ax[0].plot(np.mean(modelosses, axis=0))
ax[0].plot(np.mean(modeleval_losses, axis=0))
ax[0].set_title('LSTM loss')
ax[0].set_ylabel('loss')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'val'], loc='upper right')
ax[1].plot(np.mean(modelacc,axis=0))
ax[1].plot(np.mean(modeleval_acc, axis=0))
ax[1].set_title('LSTM accuracy')
ax[1].set_ylabel('accuracy')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'val'], loc='upper left')
plt.show()
# fig.savefig('lstm_leaveout_patients_loss_and_accuracy.jpg')
